# %%
if(! require("BiocManager", quietly = TRUE))
  install.packages("BiocManager")
BiocManager::install("fgsea")
BiocManager::install("msigdbr")
if (!requireNamespace("AnnotationDbi", quietly = TRUE)) {
  BiocManager::install("AnnotationDbi")
}
if (!requireNamespace("org.Hs.eg.db", quietly = TRUE)) {
  BiocManager::install("org.Hs.eg.db")
}
BiocManager::install("clusterProfiler", force = TRUE)
install.packages("msigdbdf", repos = "https://igordot.r-universe.dev")
install.packages("pheatmap")

library(tidyverse)
library(fgsea)
library(AnnotationDbi)
library(org.Hs.eg.db)
library(stringr)
library(ggplot2)
library(msigdbr)
library(clusterProfiler)
library(tibble)
library(dplyr)
library(pheatmap)
library(tidyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'BiocVersion', 'fgsea'
#
# also installing the dependencies ‘formatR’, ‘lambda.r’, ‘futile.options’, ‘futile.logger’, ‘snow’, ‘BiocParallel’, ‘cowplot’, ‘fastmatch’, ‘BH’
#
#
# Old packages: 'systemfonts', 'textshaping', 'utf8'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'msigdbr'
#
# also installing the dependencies ‘assertthat’, ‘babelgene’
#
#
# Old packages: 'systemfonts', 'textshaping', 'utf8'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'AnnotationDbi'
#
# also installing the dependencies ‘UCSC.utils’, ‘GenomeInfoDbData’, ‘XVector’, ‘GenomeInfoDb’, ‘plogr’, ‘png’, ‘Biostrings’, ‘BiocGenerics’, ‘Biobase’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’, ‘KEGGREST’
#
#
# Old packages: 'systemfonts', 'textshaping', 'utf8'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'org.Hs.eg.db'
#
# Old packages: 'systemfonts', 'textshaping', 'utf8'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'clusterProfiler'
#
# also installing the dependencies ‘gridGraphics’, ‘tweenr’, ‘polyclip’, ‘RcppEigen’, ‘lazyeval’, ‘ggplotify’, ‘patchwork’, ‘ggforce’, ‘ape’, ‘tidytree’, ‘treeio’, ‘R.oo’, ‘R.methodsS3’, ‘reshape2’, ‘aplot’, ‘ggfun’, ‘ggnewscale’, ‘ggrepel’, ‘ggtangle’, ‘scatterpie’, ‘ggtree’, ‘R.utils’, ‘DOSE’, ‘enrichplot’, ‘GO.db’, ‘GOSemSim’, ‘gson’, ‘igraph’, ‘plyr’, ‘qvalue’, ‘yulab.utils’
#
#
# Old packages: 'systemfonts', 'textshaping', 'utf8'
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “unable to access index for repository https://igordot.r-universe.dev/src/contrib:
#   cannot open URL 'https://igordot.r-universe.dev/src/contrib/PACKAGES'”
# Warning message:
# “package ‘msigdbdf’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: generics
#
#
# Attaching package: ‘generics’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     as.difftime
#
#
# The following object is masked from ‘package:dplyr’:
#
#     explain
#
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     second, second<-
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     %within%
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
#
# For full functionality, please install the 'msigdbdf' package with:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
#
#
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# The following object is masked from ‘package:IRanges’:
#
#     slice
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# The following object is masked from ‘package:purrr’:
#
#     simplify
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %% [markdown]
# Extracting the chemical name to try and make processing easier

# %%
#x <- "BPC"
x <- "BPA"
control_files <- list()
#con_lis <- list("0.0005", "0.001", "0.01", "0.1", "0.5", "1", "5", "10", "50", "100")
con_lis <- list("1", "5", "10")
for (i in con_lis){
  control_files[[paste0(x, i)]] = paste0("log2foldsorted_file_", x, i, "vsDMSO.csv")
  #control_files[[paste0(x, i)]] = paste0("log2foldsorted_file_", x, i, ".csv")
}
print(control_files)
# Out:
# $BPA1
# [1] "log2foldsorted_file_BPA1vsDMSO.csv"
#
# $BPA5
# [1] "log2foldsorted_file_BPA5vsDMSO.csv"
#
# $BPA10
# [1] "log2foldsorted_file_BPA10vsDMSO.csv"

# %%
#control_files = list("BPC100" = "/content/log2foldsorted_file_BPC100.csv")

# %%
# this method genes the gene pathways and genes associated to the subcomponent and then converts it into a dictionary of lists like structure
get_pathway_genes <- function(category, subcat = NULL){
if (!is.null(subcat)) {
  data <- msigdbr(species = "Homo sapiens", category = category, subcategory = subcat)
  } else {
    data <- msigdbr(species = "Homo sapiens", category = category)
  }
  subgroups <- split(data$gene_symbol, data$gs_name)
  return(subgroups)
}
# this methods is just converting the ensemble IDs from featureCounts to gene symbols and only keeping the stat and gene name column
get_stats <- function(x){
  data <- read.csv(x)
  data$gene <- gsub("\\..*", "", data$gene)
  data$gene_symbol <- mapIds(org.Hs.eg.db,
                             keys = data$gene,
                             column = "SYMBOL",
                             keytype = "ENSEMBL",
                             multiVals = "first")
  data <- na.omit(data)
  data <- data[!duplicated(data$gene_symbol), ]
  rel_cols <- data[, c("gene_symbol", "stat")]
  return(deframe(rel_cols))
}
subcategories <- list(
  list(category = "C5", subcategory = "GO:BP"),
  list(category = "C5", subcategory = "GO:CC"),
  list(category = "C5", subcategory = "GO:MF"),
  list(category = "H", subcategory = NULL) # Hallmark pathways
)

# %%
my_stats <- get_stats(control_files[[paste0(x, 10)]])
pathway_genes <- get_pathway_genes("H")

cat("Genes in stats:", length(my_stats), "\n")
cat("Unique genes in pathways:", length(unique(unlist(pathway_genes))), "\n") # confirming the whole package is installed
cat("Common genes:", length(intersect(names(my_stats), unique(unlist(pathway_genes)))), "\n")
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message:
# “The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.”
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# Genes in stats: 9111
# Unique genes in pathways: 4384
# Common genes: 2544

# %%
sig_pathway_counts <- list() # for counts of pathways (this is a list of dataframes)

sig_pathways_by_component <- list( # for common pathways
  "GO:BP" = list(),
  "GO:CC" = list(),
  "GO:MF" = list(),
  "H" = list()
)

heatmap_data_list <- list() # for heatmaps

for (i in names(control_files)) {
  file <- control_files[[i]]
  my_stats <- get_stats(file)
  #print(my_stats)
  my_stats
  my_stats <- my_stats[!is.na(names(my_stats)) & is.finite(my_stats)] # remove NAs and infinite values
  score_type <- if (all(my_stats > 0)) "pos" else if (all(my_stats < 0)) "neg" else "std"
for (subcat_info in subcategories) {
    catg <- subcat_info$category
    subcat <- subcat_info$subcategory
    pathway_genes <- get_pathway_genes(category = catg, subcat = subcat)
    pathway_genes <- pathway_genes[lengths(pathway_genes) > 0]
    if (length(pathway_genes) == 0) {
    warning(paste("Genes missing for:", subcat_info))
    next}
    #my_stats <- my_stats[names(my_stats) %in% unlist(pathway_genes)]

    # if (length(my_stats) == 0) {
    #   warning(paste("Something is wrong in:", j))
    #   next
    # }
    res <- fgsea(
      pathways = pathway_genes,
      stats = my_stats,
      eps = 0.0,
      scoreType = score_type,
      minSize = 10,
      maxSize = 500
    )

    sig_count <- sum(res$padj < 0.05, na.rm = TRUE)
    sig_pathway_counts[[length(sig_pathway_counts) + 1]] <- data.frame(
    concentration = i,
    category = ifelse(is.null(subcat), catg, subcat),
    sig_count = sig_count)

    sig_pathways <- res[padj < 0.05, pathway]
    sig_pathways_by_component[[ifelse(is.null(subcat), catg, subcat)]][[i]] <- sig_pathways

    #top 10 up and down pathways
    res_clean <- res[!is.na(padj)]
    topPathwaysUp <- res_clean[NES > 0][order(padj)][1:10, pathway]
    topPathwaysDown <- res_clean[NES < 0][order(padj)][1:10, pathway]
    topPathways <- unique(c(topPathwaysUp, topPathwaysDown))

    top_res <- res[pathway %in% topPathways, .(pathway, NES)]
    top_res$concentration <- i
    top_res$subcomponent <- ifelse(is.null(subcat), catg, subcat)

    heatmap_data_list[[paste(i, ifelse(is.null(subcat), catg, subcat), sep = "_")]] <- top_res
    print(subcat_info)
    print(plotGseaTable(
      pathway_genes[topPathways],
      my_stats,
      res,
      gseaParam = 0.5,
      colwidths = c(10, 3, 0.8, 1.2, 1.2),
      pathwayLabelStyle = list(size = 8, color = "black"),
      valueStyle = list(size = 8)
    ))
    ggsave(paste(i,ifelse(is.null(subcat), catg, subcat), "top_and_bottom_pathways_fgsea_results.png", sep = "_"))
    #top_leading_edge_genes[, leadingEdge := sapply(leadingEdge, paste, collapse = ";")]
    #write.csv(top_leading_edge_genes, paste0(i, "_", j, "_leading_edge_genes.csv"), row.names = FALSE)
  }
}
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message:
# “The `subcategory` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `subcollection` argument instead.”
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:BP"
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:CC"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:MF"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "H"
#
# $subcategory
# NULL
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
#
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:BP"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:CC"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:MF"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "H"
#
# $subcategory
# NULL
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
#
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:BP"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:CC"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "C5"
#
# $subcategory
# [1] "GO:MF"
# plot without title
# Saving 7 x 7 in image
# The 'msigdbdf' package must be installed to access the full dataset.
#
# Please run the following command to install the 'msigdbdf' package:
# install.packages('msigdbdf', repos = 'https://igordot.r-universe.dev')
# $category
# [1] "H"
#
# $subcategory
# NULL
# plot without title
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# CREATING STACKED GRAPHS  FOR DIFFERENTIALLY EXPRESSED PATHWAYS:

# %%
sig_df <- bind_rows(sig_pathway_counts)
sig_df$category <- factor(sig_df$category,
                          levels = c("GO:BP", "GO:CC", "GO:MF"),
                          labels = c("Biological Process", "Cellular Component", "Molecular Function"))
recode_map <- setNames(paste0(con_lis, " µM"), paste0(x, con_lis))
sig_df$concentration <- recode(sig_df$concentration, !!!recode_map)
sig_df$concentration <- factor(sig_df$concentration,
    levels = c("0.0005 µM", "0.001 µM", "0.01 µM", "0.1 µM", "0.5 µM", "1 µM", "5 µM", "10 µM", "50 µM", "100 µM"))
ggplot(sig_df, aes(x = concentration, y = sig_count, fill = category)) +
  geom_bar(stat = "identity") +
  labs(
    x = "BPC Concentration (µM)",
    y = "Number of Significantly Enriched Pathways (padj < 0.05)",
    fill = "GO Category",
    title = "Differentially Enriched GO Pathways Across BPC Doses"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Finding commmon pathways among all concentrations:

# %%
top3 <- c(paste0(x,"100"), paste0(x,"5"), paste0(x,"10"))

common_pathways <- lapply(sig_pathways_by_component, function(pathway_lists) {
  top_pathways_only <- pathway_lists[names(pathway_lists) %in% top3]
  Reduce(intersect, top_pathways_only)
})

print(common_pathways$`GO:BP`)
print(common_pathways$`GO:CC`)
print(common_pathways$`GO:MF`)
# Out:
# [1] "GOBP_ACTIN_FILAMENT_BASED_PROCESS"
# [2] "GOBP_ACTIN_FILAMENT_ORGANIZATION"
# [3] "GOBP_CIRCULATORY_SYSTEM_PROCESS"
# [4] "GOBP_IMPORT_INTO_CELL"
# [5] "GOBP_NEGATIVE_REGULATION_OF_MULTICELLULAR_ORGANISMAL_PROCESS"
# [6] "GOBP_REGULATION_OF_CELL_CYCLE_PHASE_TRANSITION"
# [7] "GOBP_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION"
# [1] "GOCC_ACTIN_CYTOSKELETON"           "GOCC_ACTIN_FILAMENT_BUNDLE"
# [3] "GOCC_ACTOMYOSIN"                   "GOCC_CELL_CELL_JUNCTION"
# [5] "GOCC_CELL_LEADING_EDGE"            "GOCC_POLYMERIC_CYTOSKELETAL_FIBER"
# [7] "GOCC_SUPRAMOLECULAR_POLYMER"
# character(0)

# %% [markdown]
# COMPARING THE DATA WITH THE 50 GENE BIOMARKERS FOR ESTROGEN RESPONSE

# %%
file <- read.csv("/content/biomarkers.csv")
biomarker_df <- file[!is.na(file$Fold.change.in.the.46.gene.ER.Biomarker), ]
biomarker_genes <- biomarker_df$Gene
reference_fc <- biomarker_df$Fold.change.in.the.46.gene.ER.Biomarker
names(reference_fc) <- biomarker_genes
biomarker_gene_set <- list("Estrogen_Biomarkers" = biomarker_genes)
lfc_matrix <- data.frame(Gene = biomarker_genes)
for (i in names(control_files)) {
  file <- control_files[[i]]
  stats <- get_stats(file)
  stats <- sort(stats, decreasing = TRUE)
  stats <- stats[!is.na(names(stats)) & is.finite(stats)]
  estrogen_res <- fgsea(pathways = biomarker_gene_set, stats = stats, scoreType = "std", minSize = 1, maxSize = 500)
  print(estrogen_res)
  topPathwaysUp <- estrogen_res[ES > 0][head(order(pval), n = 10), pathway]
  topPathwaysDown <- estrogen_res[ES < 0][head(order(pval), n = 10), pathway]
  topPathways <- c(topPathwaysUp, rev(topPathwaysDown))
  print(plotGseaTable(
    biomarker_gene_set[topPathways],
    stats,
    estrogen_res,
    gseaParam = 0.5,
    colwidths = c(10, 3, 0.8, 1.2, 1.2),
    pathwayLabelStyle = list(size = 8, color = "black"),
    valueStyle = list(size = 8)
  ))
  common_genes <- intersect(biomarker_genes, names(stats))
  estrogen_gene_stats <- data.frame(
    Gene                = common_genes,
    Log2FC              = stats[common_genes],
    Reference           = reference_fc[common_genes],
    Regulation          = ifelse(stats[common_genes] > 0, "Upregulated", "Downregulated"),
    Reference_Regulation = ifelse(reference_fc[common_genes] > 0, "Upregulated", "Downregulated")
  )
  print(estrogen_gene_stats)
  match_up <- sum(estrogen_gene_stats$Reference_Regulation == "Upregulated" & estrogen_gene_stats$Regulation == "Upregulated")
  match_down <- sum(estrogen_gene_stats$Reference_Regulation == "Downregulated" & estrogen_gene_stats$Regulation == "Downregulated")
  total_up <- sum(estrogen_gene_stats$Reference_Regulation == "Upregulated")
  total_down <- sum(estrogen_gene_stats$Reference_Regulation == "Downregulated")
  cat("Upregulated match:", match_up, "out of", total_up, "\n")
  cat("Downregulated match:", match_down, "out of", total_down, "\n")
  temp_df <- data.frame(Gene = common_genes, log2FC = stats[common_genes])
  colnames(temp_df)[2] <- i
  lfc_matrix <- full_join(lfc_matrix, temp_df, by = "Gene")
}

lfc_matrix$Reference <- reference_fc[lfc_matrix$Gene]
rownames(lfc_matrix) <- lfc_matrix$Gene
lfc_matrix <- lfc_matrix[, -1]
recode_map <- setNames(paste0(con_lis, " µM"), paste0(x, con_lis))
lfc_matrix <- lfc_matrix %>%
  rename_with(~ recode(., !!!recode_map))
ordered_cols <- c("Reference", "0.0005 µM", "0.001 µM", "0.01 µM", "0.1 µM", "0.5 µM", "1 µM", "5 µM", "10 µM", "50 µM", "100 µM")
lfc_matrix <- lfc_matrix[, intersect(ordered_cols, colnames(lfc_matrix))]
lfc_matrix[!is.finite(as.matrix(lfc_matrix))] <- 0
lfc_matrix_t <- t(lfc_matrix)
n_genes <- ncol(lfc_matrix_t)
n_conditions <- nrow(lfc_matrix_t)
cell_width <- 0.4
cell_height <- 0.4
pdf("BPC_biomarker_heatmap.pdf", width = 12, height = 8)
pheatmap(
  mat = lfc_matrix_t,
  cluster_rows = FALSE,
  cluster_cols = TRUE,
  display_numbers = round(lfc_matrix_t, 2),
  main = "Estrogen Biomarker Log2FC vs Estradiol Doses",
  fontsize_col = 8,
  fontsize_row = 10,
  angle_col = 90,
  color = colorRampPalette(c("blue", "white", "red"))(200),
  na_col = "grey90",
  gaps_row = 1,
  border_color = NA
)
dev.off()
# Out:
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj   log2err         ES       NES  size
#                 <char>     <num>     <num>     <num>      <num>     <num> <int>
# 1: Estrogen_Biomarkers 0.3075506 0.3075506 0.1020801 -0.3145443 -1.112484    37
#     leadingEdge
#          <list>
# 1: NMRK1, P....
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# RET           RET  0.133651384    1.6957   Upregulated          Upregulated
# PGR           PGR -0.556925875    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12  0.227025778    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.294229332    1.4629 Downregulated          Upregulated
# CA12         CA12  0.252241560    1.3283   Upregulated          Upregulated
# MYB           MYB  0.102844679    1.2700   Upregulated          Upregulated
# AREG         AREG -0.197122972    1.5957 Downregulated          Upregulated
# RCL1         RCL1  0.202546622    1.2917   Upregulated          Upregulated
# CD44         CD44  0.071138573    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.221459172   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.342827254   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.222612613   -1.5171   Upregulated        Downregulated
# TFPI         TFPI  0.018857604   -1.4943   Upregulated        Downregulated
# TFAP2A     TFAP2A  0.073301043   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.368656936   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.306125892   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.162288523   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.091246326   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.317621368   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.602415870   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.387405691   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.220494577   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2  0.131874827    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.047907180    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.232823997    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.014440966    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.095634847    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.526832589    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.155599635    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.063793529    1.4217   Upregulated          Upregulated
# SVIL         SVIL -0.003082922    1.4400 Downregulated          Upregulated
# ABHD2       ABHD2  0.114215068    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.277941132    1.4729 Downregulated          Upregulated
# NMRK1       NMRK1 -0.729174171    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.045723499    1.6717   Upregulated          Upregulated
# SGK1         SGK1  0.191665064    1.8114   Upregulated          Upregulated
# MYBL1       MYBL1  0.173318696    1.9014   Upregulated          Upregulated
# Upregulated match: 17 out of 24
# Downregulated match: 7 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway       pval       padj   log2err         ES       NES
#                 <char>      <num>      <num>     <num>      <num>     <num>
# 1: Estrogen_Biomarkers 0.05956679 0.05956679 0.2489111 -0.4057413 -1.416188
#     size  leadingEdge
#    <int>       <list>
# 1:    38 FOXC1, P....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.612010635    1.3686 Downregulated          Upregulated
# RET           RET  0.007957607    1.6957   Upregulated          Upregulated
# PGR           PGR -0.573188026    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.346949828    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.054117856    1.4629 Downregulated          Upregulated
# CA12         CA12  0.115504523    1.3283   Upregulated          Upregulated
# MYB           MYB -0.022483313    1.2700 Downregulated          Upregulated
# AREG         AREG  0.001728621    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.122804861    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.144915327    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.228418851   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.516754629   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.432270004   -1.5171   Upregulated        Downregulated
# TFPI         TFPI  0.115688626   -1.4943   Upregulated        Downregulated
# TFAP2A     TFAP2A  0.104890785   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.140456529   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.256350989   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.405548188   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.071665096   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.260210959   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.479888933   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.266406125   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.304199030   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.083014368    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.159046703    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.533627250    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.196663618    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.116948445    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.844234397    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.012311185    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C -0.023069304    1.4217 Downregulated          Upregulated
# SVIL         SVIL -0.024428875    1.4400 Downregulated          Upregulated
# ABHD2       ABHD2 -0.081783639    1.4543 Downregulated          Upregulated
# SMOX         SMOX -0.007175918    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR -0.037112109    1.5783 Downregulated          Upregulated
# NMRK1       NMRK1 -0.307158792    1.6229 Downregulated          Upregulated
# SGK1         SGK1 -0.318594234    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  0.010319747    1.9014   Upregulated          Upregulated
# Upregulated match: 9 out of 25
# Downregulated match: 7 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway       pval       padj  log2err         ES       NES
#                 <char>      <num>      <num>    <num>      <num>     <num>
# 1: Estrogen_Biomarkers 0.08183633 0.08183633 0.222056 -0.3864297 -1.386144
#     size  leadingEdge
#    <int>       <list>
# 1:    38 PRSS23, ....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.809947603    1.3686 Downregulated          Upregulated
# RET           RET -0.050087731    1.6957 Downregulated          Upregulated
# PGR           PGR -0.805058567    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.109907460    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.110238891    1.4629 Downregulated          Upregulated
# CA12         CA12  0.075088747    1.3283   Upregulated          Upregulated
# MYB           MYB -0.061712618    1.2700 Downregulated          Upregulated
# AREG         AREG  0.154525783    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.402815454    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.243064616    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.209885882   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.265387754   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.256309636   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.296527985   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.082838075   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.255221426   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.301025227   -1.4450 Downregulated        Downregulated
# ID3           ID3  0.005474744   -1.4200   Upregulated        Downregulated
# DYRK2       DYRK2  0.057943976   -1.3517   Upregulated        Downregulated
# KYNU         KYNU -0.222784117   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.418888230   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.292446671   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.332823140   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2  0.010746010    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.196001360    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.358317294    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.305203198    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.195593917    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1  0.007663570    1.4200   Upregulated          Upregulated
# CCND1       CCND1 -0.018191636    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C  0.062467285    1.4217   Upregulated          Upregulated
# SVIL         SVIL -0.086878242    1.4400 Downregulated          Upregulated
# ABHD2       ABHD2  0.042224657    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.128603629    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.013230794    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.234385380    1.6229 Downregulated          Upregulated
# SGK1         SGK1 -0.397316433    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.097049465    1.9014 Downregulated          Upregulated
# Upregulated match: 11 out of 25
# Downregulated match: 6 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway     pval     padj    log2err         ES        NES  size
#                 <char>    <num>    <num>      <num>      <num>      <num> <int>
# 1: Estrogen_Biomarkers 0.472549 0.472549 0.08108021 -0.2810866 -0.9844462    38
#     leadingEdge
#          <list>
# 1: FOXC1, P....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.56144256    1.3686 Downregulated          Upregulated
# RET           RET  0.17087013    1.6957   Upregulated          Upregulated
# PGR           PGR -0.18727158    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12  0.17888500    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.13794339    1.4629   Upregulated          Upregulated
# CA12         CA12  0.05198829    1.3283   Upregulated          Upregulated
# MYB           MYB  0.17057683    1.2700   Upregulated          Upregulated
# AREG         AREG -0.24563609    1.5957 Downregulated          Upregulated
# RCL1         RCL1  0.42494098    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.17767365    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.23305426   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.07186092   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.33644850   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.56035278   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.05514773   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.26066626   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.43929801   -1.4450 Downregulated        Downregulated
# ID3           ID3  0.22447504   -1.4200   Upregulated        Downregulated
# DYRK2       DYRK2 -0.00190755   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.30973902   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.43772330   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.55088665   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.38932785   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.33122425    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.23585528    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.45330535    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.04193868    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.18333692    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.76288920    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -0.02300420    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C  0.07748446    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.18171088    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.18456336    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.09377649    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR -0.15840987    1.5783 Downregulated          Upregulated
# NMRK1       NMRK1  0.05199692    1.6229   Upregulated          Upregulated
# SGK1         SGK1 -0.25619064    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.28241038    1.9014 Downregulated          Upregulated
# Upregulated match: 13 out of 25
# Downregulated match: 7 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway        pval        padj   log2err        ES      NES
#                 <char>       <num>       <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 0.004689309 0.004689309 0.4070179 0.4843623 1.702684
#     size  leadingEdge
#    <int>       <list>
# 1:    40 RET, PDZ....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.69544376    1.3686 Downregulated          Upregulated
# PDZK1       PDZK1  1.41272650    1.4229   Upregulated          Upregulated
# RET           RET  1.58207268    1.6957   Upregulated          Upregulated
# PGR           PGR  1.05827693    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.53364704    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.90827443    1.4629   Upregulated          Upregulated
# CA12         CA12  0.45618614    1.3283   Upregulated          Upregulated
# MYB           MYB  0.82711222    1.2700   Upregulated          Upregulated
# AREG         AREG  0.42029965    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.16138797    1.2917   Upregulated          Upregulated
# CD44         CD44  0.28613310    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.16447255   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.20217657   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.51227606   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.65176225   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.03516612   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.72101217   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.53466130   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.35901396   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.25556871   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.52252279   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.51053292   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.35918177   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.62135598   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.15819383    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.45238353    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.58960371    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.12777004    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.23583821    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.25992656    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.06195394    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.07653284    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.17791263    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.69383661    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.06419665    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.20950443    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.39517018    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.01864761    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.52665338    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.02842180    1.9014   Upregulated          Upregulated
# Upregulated match: 21 out of 27
# Downregulated match: 8 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 0.0002964371 0.0002964371 0.4984931 0.5744288 1.958162
#     size  leadingEdge
#    <int>       <list>
# 1:    41 PDZK1, R....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.279449295    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  1.788360707    1.4229   Upregulated          Upregulated
# RET           RET  1.751536071    1.6957   Upregulated          Upregulated
# PGR           PGR  1.636059842    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.537012501    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.217167949    1.4629   Upregulated          Upregulated
# CA12         CA12  0.591583477    1.3283   Upregulated          Upregulated
# MYB           MYB  1.044718704    1.2700   Upregulated          Upregulated
# AREG         AREG  0.716496102    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.401800799    1.2917   Upregulated          Upregulated
# CD44         CD44  0.318601703    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.106223500   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.176401872   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.157051322   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.691510588   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.001827669   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.713273753   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.596895998   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.247599956   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.306843137   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.638183894   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.515083218   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.110495806   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.703643757   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.864367298    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.045707067    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.539875994    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.496756672    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.483406099    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.211358955    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.227598386    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.668299856    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.051104872    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.205538997    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.775756473    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.361202467    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.237533112    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.021875204    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.361173444    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.603488464    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.416651979    1.9014   Upregulated          Upregulated
# Upregulated match: 24 out of 28
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 6.995428e-07 6.995428e-07 0.6594444 0.6782278 2.182009
#     size  leadingEdge
#    <int>       <list>
# 1:    41 PDZK1, P....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.75840909    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  2.59055060    1.4229   Upregulated          Upregulated
# RET           RET  1.95400280    1.6957   Upregulated          Upregulated
# PGR           PGR  1.97641641    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.34222919    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.57969451    1.4629   Upregulated          Upregulated
# CA12         CA12  0.80227479    1.3283   Upregulated          Upregulated
# MYB           MYB  1.26813593    1.2700   Upregulated          Upregulated
# AREG         AREG  1.70135409    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.52334799    1.2917   Upregulated          Upregulated
# CD44         CD44  0.47814829    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.10620220   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.28733465   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.41509607   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.68918139   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.12508950   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.97800347   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.47881998   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.26463611   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.31783675   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.78078928   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.30184519   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1 -0.10010436   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -0.68458271   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.80324731    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.47944183    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.71874490    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.45496728    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.83394327    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.08181835    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.20258848    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.71379641    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.19980308    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.39227534    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  1.04815887    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.04674260    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.46410263    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.10314660    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.95026186    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.13973324    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.63299527    1.9014   Upregulated          Upregulated
# Upregulated match: 24 out of 28
# Downregulated match: 11 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 1.060381e-05 1.060381e-05 0.5933255 0.6274529 2.109985
#     size  leadingEdge
#    <int>       <list>
# 1:    41 PDZK1, P....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.65922281    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  2.42910520    1.4229   Upregulated          Upregulated
# RET           RET  1.90170991    1.6957   Upregulated          Upregulated
# PGR           PGR  2.04424492    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.18206184    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.74396649    1.4629   Upregulated          Upregulated
# CA12         CA12  0.76509923    1.3283   Upregulated          Upregulated
# MYB           MYB  1.37314771    1.2700   Upregulated          Upregulated
# AREG         AREG  1.69196835    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.38190030    1.2917   Upregulated          Upregulated
# CD44         CD44  0.52920925    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.12063437   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.56172848   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.87938290   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.62966088   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.08915069   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -1.00654610   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.59358361   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.77662648   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.36719892   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.87696065   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.12352448   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1 -0.01184481   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -0.58763536   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.93063113    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.17892707    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.69787776    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.39616252    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.94077929    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.02781166    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.23175622    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.46447666    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.20812317    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.31733210    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  1.01857518    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.03601209    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.17386962    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.07016343    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.51589236    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.48837812    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.68557112    1.9014   Upregulated          Upregulated
# Upregulated match: 24 out of 28
# Downregulated match: 11 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway       pval       padj   log2err        ES     NES  size
#                 <char>      <num>      <num>     <num>     <num>   <num> <int>
# 1: Estrogen_Biomarkers 0.01479861 0.01479861 0.3807304 0.4519103 1.58099    39
#     leadingEdge
#          <list>
# 1: SLC7A5, ....
# plot without title
#              Gene        Log2FC Reference    Regulation Reference_Regulation
# RET           RET -0.6568505107    1.6957 Downregulated          Upregulated
# PGR           PGR  0.1143612463    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.7904988548    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.7855312385    1.4629   Upregulated          Upregulated
# CA12         CA12  0.1821245536    1.3283   Upregulated          Upregulated
# MYB           MYB -0.7800157819    1.2700 Downregulated          Upregulated
# AREG         AREG  2.0113267557    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.2167641438    1.2917   Upregulated          Upregulated
# CD44         CD44  0.9788611557    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.3734748063   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.9545230607   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4 -0.0002077481   -1.5171 Downregulated        Downregulated
# TFPI         TFPI -1.2568581760   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.2312434784   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.5469855644   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.1069779090   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.3373979192   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2  0.6453295111   -1.3517   Upregulated        Downregulated
# KYNU         KYNU  0.1634326480   -1.3133   Upregulated        Downregulated
# PIK3R3     PIK3R3  0.1913576233   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1 -0.4965896962   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -0.8484241606   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  1.0952366198    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2 -0.2280238946    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  2.1787777834    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.7939827650    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.4794931122    1.3643 Downregulated          Upregulated
# WWC1         WWC1 -0.1849334187    1.4183 Downregulated          Upregulated
# FOXC1       FOXC1 -0.6353493057    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -0.0477878709    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C -0.2772673829    1.4217 Downregulated          Upregulated
# SVIL         SVIL  0.8765704219    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.1619066636    1.4543   Upregulated          Upregulated
# SMOX         SMOX  0.2642013596    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  1.3663388795    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.1159706023    1.6229 Downregulated          Upregulated
# JAK2         JAK2 -0.1445295313    1.6717 Downregulated          Upregulated
# SGK1         SGK1 -0.5942965487    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  0.1293192236    1.9014   Upregulated          Upregulated
# Upregulated match: 15 out of 26
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway       pval       padj   log2err         ES       NES
#                 <char>      <num>      <num>     <num>      <num>     <num>
# 1: Estrogen_Biomarkers 0.06349206 0.06349206 0.2249661 -0.4341406 -1.397359
#     size  leadingEdge
#    <int>       <list>
# 1:    33 MYB, ALA....
# plot without title
#              Gene        Log2FC Reference    Regulation Reference_Regulation
# PGR           PGR -0.7864085549    1.3750 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.4579580003    1.4629 Downregulated          Upregulated
# CA12         CA12 -1.9721384260    1.3283 Downregulated          Upregulated
# MYB           MYB -3.5719213882    1.2700 Downregulated          Upregulated
# AREG         AREG  1.2938519600    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.0449661067    1.2917   Upregulated          Upregulated
# CD44         CD44  0.5604303083    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.1668539701   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -1.2492924075   -1.7650 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.0030781585   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -1.8245285087   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.2939635456   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.3368329219   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2  0.1157665055   -1.3517   Upregulated        Downregulated
# KYNU         KYNU -0.6599816761   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3 -0.1888783546   -1.2943 Downregulated        Downregulated
# RHBDF1     RHBDF1 -0.9526086778   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -2.2287272928   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.2100242815    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  1.5862444378    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.5093363018    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.8855140651    1.3643 Downregulated          Upregulated
# WWC1         WWC1 -0.5942447143    1.4183 Downregulated          Upregulated
# FOXC1       FOXC1 -0.0001573447    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -1.1183305961    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C -1.2069702316    1.4217 Downregulated          Upregulated
# SVIL         SVIL -0.0069412644    1.4400 Downregulated          Upregulated
# ABHD2       ABHD2  0.0281455879    1.4543   Upregulated          Upregulated
# SMOX         SMOX  1.4150607597    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  1.9116650771    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1  0.0871499383    1.6229   Upregulated          Upregulated
# SGK1         SGK1 -0.2227431175    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.6374386444    1.9014 Downregulated          Upregulated
# Upregulated match: 9 out of 22
# Downregulated match: 10 out of 11
# plot without title
# pdf
#   3
# plot without title

# %%
write.csv(lfc_matrix_t,file=paste0(x,"_estroBiomarker_Mat.csv"))
