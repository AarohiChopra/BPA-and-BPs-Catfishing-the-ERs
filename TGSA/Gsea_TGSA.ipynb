# %%
if(! require("BiocManager", quietly = TRUE))
  install.packages("BiocManager")
BiocManager::install("fgsea")
BiocManager::install("msigdbr")
if (!requireNamespace("AnnotationDbi", quietly = TRUE)) {
  BiocManager::install("AnnotationDbi")
}
if (!requireNamespace("org.Hs.eg.db", quietly = TRUE)) {
  BiocManager::install("org.Hs.eg.db")
}
BiocManager::install("clusterProfiler", force = TRUE)
install.packages("msigdbdf", repos = "https://igordot.r-universe.dev")
install.packages("pheatmap")

library(tidyverse)
library(fgsea)
library(AnnotationDbi)
library(org.Hs.eg.db)
library(stringr)
library(ggplot2)
library(msigdbr)
library(clusterProfiler)
library(tibble)
library(dplyr)
library(pheatmap)
library(tidyr)
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'fgsea'
#
# also installing the dependency ‘BiocParallel’
#
#
# Old packages: 'pkgdown'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'msigdbr'
#
# also installing the dependencies ‘assertthat’, ‘babelgene’
#
#
# Old packages: 'pkgdown'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'AnnotationDbi'
#
# also installing the dependencies ‘UCSC.utils’, ‘GenomeInfoDbData’, ‘XVector’, ‘GenomeInfoDb’, ‘plogr’, ‘png’, ‘Biostrings’, ‘BiocGenerics’, ‘Biobase’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’, ‘KEGGREST’
#
#
# Old packages: 'pkgdown'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'org.Hs.eg.db'
#
# Old packages: 'pkgdown'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.25), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'clusterProfiler'
#
# also installing the dependencies ‘gridGraphics’, ‘tweenr’, ‘polyclip’, ‘RcppEigen’, ‘lazyeval’, ‘ggplotify’, ‘patchwork’, ‘ggforce’, ‘ape’, ‘tidytree’, ‘treeio’, ‘R.oo’, ‘R.methodsS3’, ‘reshape2’, ‘aplot’, ‘ggfun’, ‘ggnewscale’, ‘ggrepel’, ‘ggtangle’, ‘scatterpie’, ‘ggtree’, ‘R.utils’, ‘DOSE’, ‘enrichplot’, ‘GO.db’, ‘GOSemSim’, ‘gson’, ‘igraph’, ‘plyr’, ‘qvalue’, ‘yulab.utils’
#
#
# Old packages: 'pkgdown'
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: generics
#
#
# Attaching package: ‘generics’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     as.difftime
#
#
# The following object is masked from ‘package:dplyr’:
#
#     explain
#
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     second, second<-
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     %within%
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
#
#
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# The following object is masked from ‘package:IRanges’:
#
#     slice
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# The following object is masked from ‘package:purrr’:
#
#     simplify
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %% [markdown]
# Extracting the chemical name to try and make processing easier

# %%
cat("Enter a chemical name: ")
x <- readline()
control_files <- list()
con_lis <- list("0.0005", "0.001", "0.01", "0.1", "0.5", "1", "5", "10", "50", "100")
for (i in con_lis){
  control_files[[paste0(x, i)]] = paste0("log2foldsorted_file_", x, i, ".csv")
}
print(control_files)
# Out:
# Enter a chemical name: TGSA
# $TGSA0.0005
# [1] "log2foldsorted_file_TGSA0.0005.csv"
#
# $TGSA0.001
# [1] "log2foldsorted_file_TGSA0.001.csv"
#
# $TGSA0.01
# [1] "log2foldsorted_file_TGSA0.01.csv"
#
# $TGSA0.1
# [1] "log2foldsorted_file_TGSA0.1.csv"
#
# $TGSA0.5
# [1] "log2foldsorted_file_TGSA0.5.csv"
#
# $TGSA1
# [1] "log2foldsorted_file_TGSA1.csv"
#
# $TGSA5
# [1] "log2foldsorted_file_TGSA5.csv"
#
# $TGSA10
# [1] "log2foldsorted_file_TGSA10.csv"
#
# $TGSA50
# [1] "log2foldsorted_file_TGSA50.csv"
#
# $TGSA100
# [1] "log2foldsorted_file_TGSA100.csv"

# %%
# this method genes the gene pathways and genes associated to the subcomponent and then converts it into a dictionary of lists like structure
get_pathway_genes <- function(subcat){
  data <- msigdbr(species = "Homo sapiens", category = "C5", subcategory = subcat)
  subgroups <- split(data$gene_symbol, data$gs_name)
  return(subgroups)
}
# this methods is just converting the ensemble IDs from featureCounts to gene symbols and only keeping the stat and gene name column
get_stats <- function(x){
  data <- read.csv(x)
  data$gene <- gsub("\\..*", "", data$gene)
  data$gene_symbol <- mapIds(org.Hs.eg.db,
                             keys = data$gene,
                             column = "SYMBOL",
                             keytype = "ENSEMBL",
                             multiVals = "first")
  data <- na.omit(data)
  data <- data[!duplicated(data$gene_symbol), ]
  rel_cols <- data[, c("gene_symbol", "stat")]
  return(deframe(rel_cols))
}
subcategories <- c("GO:BP", "GO:CC", "GO:MF")

# %%
my_stats <- get_stats(control_files[[paste0(x, 100)]])
pathway_genes <- get_pathway_genes("GO:BP")

cat("Genes in stats:", length(my_stats), "\n")
cat("Unique genes in pathways:", length(unique(unlist(pathway_genes))), "\n") # confirming the whole package is installed
cat("Common genes:", length(intersect(names(my_stats), unique(unlist(pathway_genes)))), "\n")
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message:
# “The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.”
# Warning message:
# “The `subcategory` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `subcollection` argument instead.”
# Genes in stats: 8939
# Unique genes in pathways: 17951
# Common genes: 7893

# %%
sig_pathway_counts <- list() # for counts of pathways (this is a list of dataframes)

sig_pathways_by_component <- list( # for common pathways
  "GO:BP" = list(),
  "GO:CC" = list(),
  "GO:MF" = list()
)

heatmap_data_list <- list() # for heatmaps

for (i in names(control_files)) {
  file <- control_files[[i]]
  my_stats <- get_stats(file)
  #print(my_stats)
  my_stats
  my_stats <- my_stats[!is.na(names(my_stats)) & is.finite(my_stats)] # remove NAs and infinite values

  score_type <- if (all(my_stats > 0)) "pos" else if (all(my_stats < 0)) "neg" else "std"

  for (j in subcategories) {
    pathway_genes <- get_pathway_genes(j)
    pathway_genes <- pathway_genes[lengths(pathway_genes) > 0]
    if (length(pathway_genes) == 0) {
    warning(paste("Genes missing for:", j))
    next}
    #my_stats <- my_stats[names(my_stats) %in% unlist(pathway_genes)]

    # if (length(my_stats) == 0) {
    #   warning(paste("Something is wrong in:", j))
    #   next
    # }
    res <- fgsea(
      pathways = pathway_genes,
      stats = my_stats,
      eps = 0.0,
      scoreType = score_type,
      minSize = 10,
      maxSize = 500
    )

    sig_count <- sum(res$padj < 0.05, na.rm = TRUE)
    sig_pathway_counts[[length(sig_pathway_counts) + 1]] <- data.frame(
    concentration = i,
    category = j,
    sig_count = sig_count)

    sig_pathways <- res[padj < 0.05, pathway]
    sig_pathways_by_component[[j]][[i]] <- sig_pathways

    #top 10 up and down pathways
    res_clean <- res[!is.na(padj)]
    topPathwaysUp <- res_clean[NES > 0][order(padj)][1:10, pathway]
    topPathwaysDown <- res_clean[NES < 0][order(padj)][1:10, pathway]
    topPathways <- unique(c(topPathwaysUp, topPathwaysDown))

    top_res <- res[pathway %in% topPathways, .(pathway, NES)]
    top_res$concentration <- i
    top_res$subcomponent <- j

    heatmap_data_list[[paste(i, j, sep = "_")]] <- top_res

    print(plotGseaTable(
      pathway_genes[topPathways],
      my_stats,
      res,
      gseaParam = 0.5,
      colwidths = c(10, 3, 0.8, 1.2, 1.2),
      pathwayLabelStyle = list(size = 8, color = "black"),
      valueStyle = list(size = 8)
    ))
    ggsave(paste(i,j, "top_and_bottom_pathways_fgsea_results.png", sep = "_"))
    #top_leading_edge_genes[, leadingEdge := sapply(leadingEdge, paste, collapse = ";")]
    #write.csv(top_leading_edge_genes, paste0(i, "_", j, "_leading_edge_genes.csv"), row.names = FALSE)
  }
}
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# CREATING STACKED GRAPHS  FOR DIFFERENTIALLY EXPRESSED PATHWAYS:

# %%
sig_df <- bind_rows(sig_pathway_counts)
sig_df$category <- factor(sig_df$category,
                          levels = c("GO:BP", "GO:CC", "GO:MF"),
                          labels = c("Biological Process", "Cellular Component", "Molecular Function"))
recode_map <- setNames(paste0(con_lis, " µM"), paste0(x, con_lis))
sig_df$concentration <- recode(sig_df$concentration, !!!recode_map)
sig_df$concentration <- factor(sig_df$concentration,
    levels = c("0.0005 µM", "0.001 µM", "0.01 µM", "0.1 µM", "0.5 µM", "1 µM", "5 µM", "10 µM", "50 µM", "100 µM"))
ggplot(sig_df, aes(x = concentration, y = sig_count, fill = category)) +
  geom_bar(stat = "identity") +
  labs(
    x = "TGSA Concentration (µM)",
    y = "Number of Significantly Enriched Pathways (padj < 0.05)",
    fill = "GO Category",
    title = "Differentially Enriched GO Pathways Across TGSA Doses"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Finding commmon pathways among all concentrations:

# %%
top3 <- c(paste0(x, "5"), paste0(x, "50"), paste0(x, "10")) # only looking at conc with most patwhays, excludinh 100 as we have seen a flip so dont expect much common pathways

common_pathways <- lapply(sig_pathways_by_component, function(pathway_lists){
  top_pathways_only <- pathway_lists[names(pathway_lists) %in% top3]
  Reduce(intersect, top_pathways_only)})
print(common_pathways$`GO:BP`)
print(common_pathways$`GO:CC`)
print(common_pathways$`GO:MF`)
# Out:
# character(0)
# [1] "GOCC_CYTOSOLIC_LARGE_RIBOSOMAL_SUBUNIT"
# [2] "GOCC_CYTOSOLIC_RIBOSOME"
# [3] "GOCC_LARGE_RIBOSOMAL_SUBUNIT"
# [4] "GOCC_MITOCHONDRIAL_MATRIX"
# [5] "GOCC_MITOCHONDRIAL_PROTEIN_CONTAINING_COMPLEX"
# [6] "GOCC_ORGANELLE_INNER_MEMBRANE"
# [7] "GOCC_RIBOSOMAL_SUBUNIT"
# [8] "GOCC_RIBOSOME"
# [9] "GOCC_SMALL_RIBOSOMAL_SUBUNIT"
# [1] "GOMF_STRUCTURAL_CONSTITUENT_OF_RIBOSOME"

# %% [markdown]
# To comapre against the estradiol conc we will also look at some more concs

# %%
top3 <- c(paste0(x, "0.0005"), paste0(x, "0.001"), paste0(x, "0.01")) # only looking at conc with most patwhays, excludinh 100 as we have seen a flip so dont expect much common pathways

common_pathways <- lapply(sig_pathways_by_component, function(pathway_lists){
  top_pathways_only <- pathway_lists[names(pathway_lists) %in% top3]
  Reduce(intersect, top_pathways_only)})
print(common_pathways$`GO:BP`)
print(common_pathways$`GO:CC`)
print(common_pathways$`GO:MF`)
# Out:
# character(0)
# character(0)
# character(0)

# %% [markdown]
# COMPARING THE DATA WITH THE 50 GENE BIOMARKERS FOR ESTROGEN RESPONSE

# %%
file <- read.csv("/content/biomarkers.csv")
biomarker_df <- file[!is.na(file$Fold.change.in.the.46.gene.ER.Biomarker), ]
biomarker_genes <- biomarker_df$Gene
reference_fc <- biomarker_df$Fold.change.in.the.46.gene.ER.Biomarker
names(reference_fc) <- biomarker_genes
biomarker_gene_set <- list("Estrogen_Biomarkers" = biomarker_genes)
lfc_matrix <- data.frame(Gene = biomarker_genes)
for (i in names(control_files)) {
  file <- control_files[[i]]
  stats <- get_stats(file)
  stats <- sort(stats, decreasing = TRUE)
  stats <- stats[!is.na(names(stats)) & is.finite(stats)]
  estrogen_res <- fgsea(pathways = biomarker_gene_set, stats = stats, scoreType = "std", minSize = 1, maxSize = 500)
  print(estrogen_res)
  topPathwaysUp <- estrogen_res[ES > 0][head(order(pval), n = 10), pathway]
  topPathwaysDown <- estrogen_res[ES < 0][head(order(pval), n = 10), pathway]
  topPathways <- c(topPathwaysUp, rev(topPathwaysDown))
  print(plotGseaTable(
    biomarker_gene_set[topPathways],
    stats,
    estrogen_res,
    gseaParam = 0.5,
    colwidths = c(10, 3, 0.8, 1.2, 1.2),
    pathwayLabelStyle = list(size = 8, color = "black"),
    valueStyle = list(size = 8)
  ))
  common_genes <- intersect(biomarker_genes, names(stats))
  estrogen_gene_stats <- data.frame(
    Gene                = common_genes,
    Log2FC              = stats[common_genes],
    Reference           = reference_fc[common_genes],
    Regulation          = ifelse(stats[common_genes] > 0, "Upregulated", "Downregulated"),
    Reference_Regulation = ifelse(reference_fc[common_genes] > 0, "Upregulated", "Downregulated")
  )
  print(estrogen_gene_stats)
  match_up <- sum(estrogen_gene_stats$Reference_Regulation == "Upregulated" & estrogen_gene_stats$Regulation == "Upregulated")
  match_down <- sum(estrogen_gene_stats$Reference_Regulation == "Downregulated" & estrogen_gene_stats$Regulation == "Downregulated")
  total_up <- sum(estrogen_gene_stats$Reference_Regulation == "Upregulated")
  total_down <- sum(estrogen_gene_stats$Reference_Regulation == "Downregulated")
  cat("Upregulated match:", match_up, "out of", total_up, "\n")
  cat("Downregulated match:", match_down, "out of", total_down, "\n")
  temp_df <- data.frame(Gene = common_genes, log2FC = stats[common_genes])
  colnames(temp_df)[2] <- i
  lfc_matrix <- full_join(lfc_matrix, temp_df, by = "Gene")
}

lfc_matrix$Reference <- reference_fc[lfc_matrix$Gene]
rownames(lfc_matrix) <- lfc_matrix$Gene
lfc_matrix <- lfc_matrix[, -1]
recode_map <- setNames(paste0(con_lis, " µM"), paste0(x, con_lis))
lfc_matrix <- lfc_matrix %>%
  rename_with(~ recode(., !!!recode_map))
ordered_cols <- c("Reference", "0.0005 µM", "0.001 µM", "0.01 µM", "0.1 µM", "0.5 µM", "1 µM", "5 µM", "10 µM", "50 µM", "100 µM")
lfc_matrix <- lfc_matrix[, intersect(ordered_cols, colnames(lfc_matrix))]
lfc_matrix[!is.finite(as.matrix(lfc_matrix))] <- 0
lfc_matrix_t <- t(lfc_matrix)
n_genes <- ncol(lfc_matrix_t)
n_conditions <- nrow(lfc_matrix_t)
cell_width <- 0.4
cell_height <- 0.4
pdf("TGSA_biomarker_heatmap.pdf", width = 12, height = 8)
pheatmap(
  mat = lfc_matrix_t,
  cluster_rows = FALSE,
  cluster_cols = TRUE,
  display_numbers = round(lfc_matrix_t, 2),
  main = "Estrogen Biomarker Log2FC vs Estradiol Doses",
  fontsize_col = 8,
  fontsize_row = 10,
  angle_col = 90,
  color = colorRampPalette(c("blue", "white", "red"))(200),
  na_col = "grey90",
  gaps_row = 1,
  border_color = NA
)
dev.off()
# Out:
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj   log2err         ES       NES  size
#                 <char>     <num>     <num>     <num>      <num>     <num> <int>
# 1: Estrogen_Biomarkers 0.2989899 0.2989899 0.1096841 -0.3064855 -1.094021    39
#     leadingEdge
#          <list>
# 1: PGR, FOX....
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.051619831    1.3686 Downregulated          Upregulated
# RET           RET -0.051433919    1.6957 Downregulated          Upregulated
# PGR           PGR -0.588005189    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12  0.061389405    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.094124560    1.4629 Downregulated          Upregulated
# CA12         CA12  0.128578427    1.3283   Upregulated          Upregulated
# MYB           MYB -0.160215166    1.2700 Downregulated          Upregulated
# AREG         AREG -0.234055509    1.5957 Downregulated          Upregulated
# RCL1         RCL1  0.157681936    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.036166555    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.188395570   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.151083022   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4 -0.197194230   -1.5171 Downregulated        Downregulated
# TFPI         TFPI -0.039581706   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.037375739   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.281657273   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.319132187   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.040871138   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.047433171   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.223418363   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.318897280   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.455845439   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.128071751   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.520908439    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.140278996    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.101086592    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.137599019    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.157030723    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.107546360    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.556981183    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.045806377    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C -0.001843617    1.4217 Downregulated          Upregulated
# SVIL         SVIL  0.174925733    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.131514103    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.196232167    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR -0.398304208    1.5783 Downregulated          Upregulated
# NMRK1       NMRK1 -0.422624384    1.6229 Downregulated          Upregulated
# SGK1         SGK1  0.061093741    1.8114   Upregulated          Upregulated
# MYBL1       MYBL1 -0.391760126    1.9014 Downregulated          Upregulated
# Upregulated match: 12 out of 26
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj    log2err         ES       NES
#                 <char>     <num>     <num>      <num>      <num>     <num>
# 1: Estrogen_Biomarkers 0.3514493 0.3514493 0.09314546 -0.2904277 -1.057493
#     size  leadingEdge
#    <int>       <list>
# 1:    40 PRSS23, ....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.64340847    1.3686 Downregulated          Upregulated
# RET           RET -0.05502354    1.6957 Downregulated          Upregulated
# PGR           PGR -0.33284910    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.17769125    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.01211009    1.4629 Downregulated          Upregulated
# CA12         CA12  0.20158990    1.3283   Upregulated          Upregulated
# MYB           MYB -0.03171291    1.2700 Downregulated          Upregulated
# AREG         AREG -0.14134727    1.5957 Downregulated          Upregulated
# RCL1         RCL1  0.03994843    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.02267422    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.28426624   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.42907030   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4 -0.11933841   -1.5171 Downregulated        Downregulated
# TFPI         TFPI -0.05212805   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.11319416   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.13975711   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.36463570   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.13205410   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.01333636   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.27750778   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.45652107   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.38704117   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.43026496   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.69196052    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2 -0.08170254    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.22713290    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.62486413    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.11409728    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.28789490    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.38443433    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -0.12928434    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C -0.01624456    1.4217 Downregulated          Upregulated
# SVIL         SVIL  0.02591326    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.05918669    1.4543   Upregulated          Upregulated
# SMOX         SMOX  0.05747899    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  0.06336448    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.30632640    1.6229 Downregulated          Upregulated
# JAK2         JAK2 -0.26432042    1.6717 Downregulated          Upregulated
# SGK1         SGK1 -0.57416242    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.07746971    1.9014 Downregulated          Upregulated
# Upregulated match: 10 out of 27
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj    log2err         ES        NES
#                 <char>     <num>     <num>      <num>      <num>      <num>
# 1: Estrogen_Biomarkers 0.7345679 0.7345679 0.06130261 -0.2336481 -0.8516151
#     size  leadingEdge
#    <int>       <list>
# 1:    39 PRSS23, ....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.69303435    1.3686 Downregulated          Upregulated
# RET           RET -0.08370439    1.6957 Downregulated          Upregulated
# PGR           PGR -0.43344823    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.12572516    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.23449357    1.4629 Downregulated          Upregulated
# CA12         CA12 -0.04447412    1.3283 Downregulated          Upregulated
# MYB           MYB -0.33088821    1.2700 Downregulated          Upregulated
# AREG         AREG -0.26995776    1.5957 Downregulated          Upregulated
# RCL1         RCL1  0.16878622    1.2917   Upregulated          Upregulated
# CD44         CD44  0.01136059    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.25147032   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.20562537   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.38077215   -1.5171   Upregulated        Downregulated
# TFPI         TFPI  0.10607156   -1.4943   Upregulated        Downregulated
# TFAP2A     TFAP2A  0.05704930   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.10830970   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.35563354   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.11377415   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.01712181   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.22280971   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.18271498   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.34034460   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.30007435   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.90743385    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.08067810    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.20492767    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.30771486    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.05987158    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.15072672    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.40573690    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.18326110    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.03637153    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.02387864    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.04260212    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.13099525    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.29682633    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.19689413    1.6229 Downregulated          Upregulated
# SGK1         SGK1  0.06080102    1.8114   Upregulated          Upregulated
# MYBL1       MYBL1  0.01297506    1.9014   Upregulated          Upregulated
# Upregulated match: 14 out of 26
# Downregulated match: 7 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway       pval       padj   log2err         ES       NES
#                 <char>      <num>      <num>     <num>      <num>     <num>
# 1: Estrogen_Biomarkers 0.02171314 0.02171314 0.3524879 -0.4379411 -1.522984
#     size  leadingEdge
#    <int>       <list>
# 1:    38 NMRK1, P....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.502703228    1.3686 Downregulated          Upregulated
# RET           RET -0.001141036    1.6957 Downregulated          Upregulated
# PGR           PGR -0.371647252    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.300439454    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.022467418    1.4629 Downregulated          Upregulated
# CA12         CA12  0.045588508    1.3283   Upregulated          Upregulated
# MYB           MYB -0.054512547    1.2700 Downregulated          Upregulated
# AREG         AREG -0.244599729    1.5957 Downregulated          Upregulated
# RCL1         RCL1 -0.124333027    1.2917 Downregulated          Upregulated
# CD44         CD44 -0.235359299    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.308346360   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.340047909   -1.7650 Downregulated        Downregulated
# TFPI         TFPI -0.212304293   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.129143167   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.091094848   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.427176077   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.239067483   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.194664593   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.357545553   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.204261066   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.443907048   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.392866679   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.289627031    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.089161296    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.403131535    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.063592977    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.316660776    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.223158310    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -0.048272175    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C  0.045028977    1.4217   Upregulated          Upregulated
# SVIL         SVIL -0.215413232    1.4400 Downregulated          Upregulated
# ABHD2       ABHD2  0.036033880    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.173686498    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR -0.294406994    1.5783 Downregulated          Upregulated
# NMRK1       NMRK1 -0.956180689    1.6229 Downregulated          Upregulated
# JAK2         JAK2 -0.001820592    1.6717 Downregulated          Upregulated
# SGK1         SGK1  0.026466266    1.8114   Upregulated          Upregulated
# MYBL1       MYBL1 -0.202106598    1.9014 Downregulated          Upregulated
# Upregulated match: 7 out of 26
# Downregulated match: 8 out of 12
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj   log2err        ES       NES  size
#                 <char>     <num>     <num>     <num>     <num>     <num> <int>
# 1: Estrogen_Biomarkers 0.2280335 0.2280335 0.1307771 -0.324574 -1.167439    38
#     leadingEdge
#          <list>
# 1: FOXC1, P....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.42716625    1.3686 Downregulated          Upregulated
# RET           RET  0.15905932    1.6957   Upregulated          Upregulated
# PGR           PGR -0.19419484    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.18618422    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.07221413    1.4629   Upregulated          Upregulated
# CA12         CA12  0.10245538    1.3283   Upregulated          Upregulated
# MYB           MYB  0.18811267    1.2700   Upregulated          Upregulated
# AREG         AREG -0.08986297    1.5957 Downregulated          Upregulated
# RCL1         RCL1  0.10097906    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.01976585    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.25574797   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.27047390   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.05226014   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.20953506   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.12741874   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.20876621   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.41023787   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.31571283   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.14925503   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.35879868   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.73499284   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.36739756   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.41916011   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.35507846    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.15483768    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.29894591    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.07330222    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.16932303    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.70115556    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -0.05857849    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C  0.08621341    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.03744111    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.13220608    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.36126249    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR -0.11137385    1.5783 Downregulated          Upregulated
# NMRK1       NMRK1 -0.17743484    1.6229 Downregulated          Upregulated
# SGK1         SGK1 -0.33571664    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  0.02807767    1.9014   Upregulated          Upregulated
# Upregulated match: 12 out of 25
# Downregulated match: 8 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway       pval       padj   log2err         ES       NES
#                 <char>      <num>      <num>     <num>      <num>     <num>
# 1: Estrogen_Biomarkers 0.01514078 0.01514078 0.3807304 -0.4476651 -1.565295
#     size  leadingEdge
#    <int>       <list>
# 1:    38 FOXC1, C....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.213351647    1.3686 Downregulated          Upregulated
# RET           RET -0.253948487    1.6957 Downregulated          Upregulated
# PGR           PGR -0.518032266    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.585354903    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.122665839    1.4629 Downregulated          Upregulated
# CA12         CA12 -0.021712618    1.3283 Downregulated          Upregulated
# MYB           MYB  0.018862321    1.2700   Upregulated          Upregulated
# AREG         AREG -0.311353051    1.5957 Downregulated          Upregulated
# RCL1         RCL1  0.171100723    1.2917   Upregulated          Upregulated
# CD44         CD44  0.013951562    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.256767175   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.053106770   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.013575164   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.340980538   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.006423375   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.344728563   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.338483891   -1.4450 Downregulated        Downregulated
# ID3           ID3  0.024405147   -1.4200   Upregulated        Downregulated
# DYRK2       DYRK2  0.041641808   -1.3517   Upregulated        Downregulated
# KYNU         KYNU -0.279897753   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.585447463   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.252450028   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.335484182   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.468259067    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.159923459    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.219853279    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -0.082192721    1.3643 Downregulated          Upregulated
# WWC1         WWC1  0.119949849    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.630643263    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.429046220    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.075594061    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.229975267    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2 -0.014845895    1.4543 Downregulated          Upregulated
# SMOX         SMOX -0.180716288    1.4729 Downregulated          Upregulated
# NMRK1       NMRK1 -0.280086301    1.6229 Downregulated          Upregulated
# JAK2         JAK2 -0.429739018    1.6717 Downregulated          Upregulated
# SGK1         SGK1 -0.037809849    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.360269675    1.9014 Downregulated          Upregulated
# Upregulated match: 9 out of 25
# Downregulated match: 6 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj    log2err         ES        NES
#                 <char>     <num>     <num>      <num>      <num>      <num>
# 1: Estrogen_Biomarkers 0.9879032 0.9879032 0.04660151 -0.1688791 -0.5867031
#     size  leadingEdge
#    <int>       <list>
# 1:    38 PRSS23, ....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.573453328    1.3686 Downregulated          Upregulated
# RET           RET -0.028918112    1.6957 Downregulated          Upregulated
# PGR           PGR -0.296442693    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12  0.063943788    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.159920601    1.4629 Downregulated          Upregulated
# CA12         CA12  0.051297151    1.3283   Upregulated          Upregulated
# MYB           MYB -0.106803400    1.2700 Downregulated          Upregulated
# AREG         AREG  0.248159771    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.212435442    1.2917   Upregulated          Upregulated
# CD44         CD44  0.060520060    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.138771295   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.091478518   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4 -0.084244181   -1.5171 Downregulated        Downregulated
# TFPI         TFPI -0.144118145   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.043532363   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.207321423   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.272609679   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.079730162   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2  0.098751253   -1.3517   Upregulated        Downregulated
# KYNU         KYNU -0.221180054   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.395220523   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.296289604   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.352829149   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.056764372    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.214017767    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.110108789    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.011583611    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.197526595    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1  0.036626865    1.4200   Upregulated          Upregulated
# CCND1       CCND1  0.134496298    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.012320430    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.148390471    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.008332124    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.205698499    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.223819954    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.120836197    1.6229 Downregulated          Upregulated
# SGK1         SGK1  0.152536038    1.8114   Upregulated          Upregulated
# MYBL1       MYBL1 -0.087574921    1.9014 Downregulated          Upregulated
# Upregulated match: 16 out of 25
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj    log2err         ES        NES
#                 <char>     <num>     <num>      <num>      <num>      <num>
# 1: Estrogen_Biomarkers 0.8196393 0.8196393 0.05490737 -0.2225935 -0.7944845
#     size  leadingEdge
#    <int>       <list>
# 1:    37 PRSS23, ....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.50042746    1.3686 Downregulated          Upregulated
# RET           RET  0.12751384    1.6957   Upregulated          Upregulated
# PGR           PGR  0.06965396    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.40367121    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.07989225    1.4629   Upregulated          Upregulated
# CA12         CA12  0.08885622    1.3283   Upregulated          Upregulated
# MYB           MYB  0.14860979    1.2700   Upregulated          Upregulated
# AREG         AREG  0.17187378    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.13733778    1.2917   Upregulated          Upregulated
# CD44         CD44  0.44961728    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.12249052   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.11063374   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.48293632   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.47123046   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.02293488   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.30377160   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.32805708   -1.4450 Downregulated        Downregulated
# ID3           ID3  0.01256264   -1.4200   Upregulated        Downregulated
# DYRK2       DYRK2 -0.13999800   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.27975194   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.46118274   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.20802006   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.45337777   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.31136226    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.41520439    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.25033156    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.21312193    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.23315975    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.11519815    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.32666327    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C -0.01337840    1.4217 Downregulated          Upregulated
# SVIL         SVIL  0.16371940    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.04375010    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.39711827    1.4729 Downregulated          Upregulated
# NMRK1       NMRK1 -0.24283011    1.6229 Downregulated          Upregulated
# SGK1         SGK1 -0.06687628    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.03586152    1.9014 Downregulated          Upregulated
# Upregulated match: 16 out of 24
# Downregulated match: 7 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway        pval        padj   log2err        ES      NES
#                 <char>       <num>       <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 0.005119579 0.005119579 0.4070179 0.4830533 1.695745
#     size  leadingEdge
#    <int>       <list>
# 1:    39 AREG, SL....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.07821866    1.3686 Downregulated          Upregulated
# RET           RET -0.29172250    1.6957 Downregulated          Upregulated
# PGR           PGR  0.49088448    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.37620438    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.79919966    1.4629   Upregulated          Upregulated
# CA12         CA12  0.46821754    1.3283   Upregulated          Upregulated
# MYB           MYB -0.37557625    1.2700 Downregulated          Upregulated
# AREG         AREG  2.71450125    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.48869942    1.2917   Upregulated          Upregulated
# CD44         CD44  1.05299326    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.46722258   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.49449955   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.52507435   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -1.30540743   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.03238898   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.65574023   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.07328058   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.70483491   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2  0.23069307   -1.3517   Upregulated        Downregulated
# KYNU         KYNU -0.20774987   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.33761517   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1 -0.50730745   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -0.80812232   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.84887786    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2 -0.43384930    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  2.01695568    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  1.28418147    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.05865357    1.3643   Upregulated          Upregulated
# WWC1         WWC1 -0.29116634    1.4183 Downregulated          Upregulated
# FOXC1       FOXC1 -0.31928821    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.03983195    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C -0.35152009    1.4217 Downregulated          Upregulated
# SVIL         SVIL  0.78608700    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.40952400    1.4543   Upregulated          Upregulated
# SMOX         SMOX  0.15179569    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  1.09478801    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1  0.03805119    1.6229   Upregulated          Upregulated
# SGK1         SGK1 -0.63293244    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.19256115    1.9014   Upregulated          Upregulated
# Upregulated match: 18 out of 26
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj   log2err         ES       NES  size
#                 <char>     <num>     <num>     <num>      <num>     <num> <int>
# 1: Estrogen_Biomarkers 0.1552288 0.1552288 0.1412251 -0.3823905 -1.252106    35
#     leadingEdge
#          <list>
# 1: MYB, CA1....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# RET           RET -1.488949336    1.6957 Downregulated          Upregulated
# PGR           PGR -0.500391190    1.3750 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.199906823    1.4629 Downregulated          Upregulated
# CA12         CA12 -1.805514792    1.3283 Downregulated          Upregulated
# MYB           MYB -3.505939417    1.2700 Downregulated          Upregulated
# AREG         AREG  2.210752941    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.138127469    1.2917   Upregulated          Upregulated
# CD44         CD44  0.408680582    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.435653618   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -1.208850467   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.697494349   -1.5171   Upregulated        Downregulated
# TFAP2A     TFAP2A -0.199168778   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.890287046   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2  0.431950839   -1.4450   Upregulated        Downregulated
# ID3           ID3 -0.007140287   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2  0.034443761   -1.3517   Upregulated        Downregulated
# KYNU         KYNU -0.092254515   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.049016108   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1 -0.412564270   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -1.603338192   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2 -0.475439029    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  1.701399174    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  1.866564210    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -1.032469953    1.3643 Downregulated          Upregulated
# WWC1         WWC1 -0.112416594    1.4183 Downregulated          Upregulated
# FOXC1       FOXC1 -0.531615955    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -1.085199031    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C -0.973961520    1.4217 Downregulated          Upregulated
# SVIL         SVIL  0.635747043    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2 -0.160850581    1.4543 Downregulated          Upregulated
# SMOX         SMOX  0.719523727    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  2.483575314    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.126789590    1.6229 Downregulated          Upregulated
# SGK1         SGK1 -1.383600144    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.293425598    1.9014 Downregulated          Upregulated
# Upregulated match: 8 out of 23
# Downregulated match: 8 out of 12
# plot without title
# pdf
#   3
# plot without title

# %%
write.csv(lfc_matrix_t,file=paste0(x,"_estroBiomarker_Mat.csv"))
