# %%
if(! require("BiocManager", quietly = TRUE))
  install.packages("BiocManager")
BiocManager::install("fgsea")
BiocManager::install("msigdbr")
if (!requireNamespace("AnnotationDbi", quietly = TRUE)) {
  BiocManager::install("AnnotationDbi")
}
if (!requireNamespace("org.Hs.eg.db", quietly = TRUE)) {
  BiocManager::install("org.Hs.eg.db")
}
BiocManager::install("clusterProfiler", force = TRUE)
install.packages("msigdbdf", repos = "https://igordot.r-universe.dev")
install.packages("pheatmap")

library(tidyverse)
library(fgsea)
library(AnnotationDbi)
library(org.Hs.eg.db)
library(stringr)
library(ggplot2)
library(msigdbr)
library(clusterProfiler)
library(tibble)
library(dplyr)
library(pheatmap)
library(tidyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.26), R 4.5.1 (2025-06-13)
#
# Installing package(s) 'BiocVersion', 'fgsea'
#
# also installing the dependencies ‘formatR’, ‘lambda.r’, ‘futile.options’, ‘futile.logger’, ‘snow’, ‘BiocParallel’, ‘cowplot’, ‘fastmatch’, ‘BH’
#
#
# Old packages: 'dbplyr', 'dtplyr', 'ggplot2', 'googledrive'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.26), R 4.5.1 (2025-06-13)
#
# Installing package(s) 'msigdbr'
#
# also installing the dependencies ‘assertthat’, ‘babelgene’
#
#
# Old packages: 'dbplyr', 'dtplyr', 'ggplot2', 'googledrive'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.26), R 4.5.1 (2025-06-13)
#
# Installing package(s) 'AnnotationDbi'
#
# also installing the dependencies ‘UCSC.utils’, ‘GenomeInfoDbData’, ‘XVector’, ‘GenomeInfoDb’, ‘plogr’, ‘png’, ‘Biostrings’, ‘BiocGenerics’, ‘Biobase’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’, ‘KEGGREST’

# %% [markdown]
# Extracting the chemical name to try and make processing easier

# %%
cat("Enter a chemical name: ")
x <- readline()
control_files <- list()
con_lis <- list("0.0005", "0.001", "0.01", "0.1", "0.5", "1", "5", "10", "50", "100")
for (i in con_lis){
  control_files[[paste0(x, i)]] = paste0("log2foldsorted_file_", x, i, "vsDMSO.csv")
}
print(control_files)
# Out:
# Enter a chemical name: BPA
# $BPA0.0005
# [1] "log2foldsorted_file_BPA0.0005vsDMSO.csv"
#
# $BPA0.001
# [1] "log2foldsorted_file_BPA0.001vsDMSO.csv"
#
# $BPA0.01
# [1] "log2foldsorted_file_BPA0.01vsDMSO.csv"
#
# $BPA0.1
# [1] "log2foldsorted_file_BPA0.1vsDMSO.csv"
#
# $BPA0.5
# [1] "log2foldsorted_file_BPA0.5vsDMSO.csv"
#
# $BPA1
# [1] "log2foldsorted_file_BPA1vsDMSO.csv"
#
# $BPA5
# [1] "log2foldsorted_file_BPA5vsDMSO.csv"
#
# $BPA10
# [1] "log2foldsorted_file_BPA10vsDMSO.csv"
#
# $BPA50
# [1] "log2foldsorted_file_BPA50vsDMSO.csv"
#
# $BPA100
# [1] "log2foldsorted_file_BPA100vsDMSO.csv"

# %%
# this method genes the gene pathways and genes associated to the subcomponent and then converts it into a dictionary of lists like structure
get_pathway_genes <- function(subcat){
  data <- msigdbr(species = "Homo sapiens", category = "C5", subcategory = subcat)
  subgroups <- split(data$gene_symbol, data$gs_name)
  return(subgroups)
}
# this methods is just converting the ensemble IDs from featureCounts to gene symbols and only keeping the stat and gene name column
get_stats <- function(x){
  data <- read.csv(x)
  data$gene <- gsub("\\..*", "", data$gene)
  data$gene_symbol <- mapIds(org.Hs.eg.db,
                             keys = data$gene,
                             column = "SYMBOL",
                             keytype = "ENSEMBL",
                             multiVals = "first")
  data <- na.omit(data)
  data <- data[!duplicated(data$gene_symbol), ]
  rel_cols <- data[, c("gene_symbol", "stat")]
  return(deframe(rel_cols))
}
subcategories <- c("GO:BP", "GO:CC", "GO:MF")

# %%
my_stats <- get_stats(control_files[[paste0(x, 100)]])
pathway_genes <- get_pathway_genes("GO:BP")

cat("Genes in stats:", length(my_stats), "\n")
cat("Unique genes in pathways:", length(unique(unlist(pathway_genes))), "\n") # confirming the whole package is installed
cat("Common genes:", length(intersect(names(my_stats), unique(unlist(pathway_genes)))), "\n")
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message:
# “The `category` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `collection` argument instead.”
# Warning message:
# “The `subcategory` argument of `msigdbr()` is deprecated as of msigdbr 10.0.0.
# ℹ Please use the `subcollection` argument instead.”
# Genes in stats: 8885
# Unique genes in pathways: 17951
# Common genes: 7854

# %%
sig_pathway_counts <- list() # for counts of pathways (this is a list of dataframes)

sig_pathways_by_component <- list( # for common pathways
  "GO:BP" = list(),
  "GO:CC" = list(),
  "GO:MF" = list()
)

heatmap_data_list <- list() # for heatmaps

for (i in names(control_files)) {
  file <- control_files[[i]]
  my_stats <- get_stats(file)
  #print(my_stats)
  my_stats
  my_stats <- my_stats[!is.na(names(my_stats)) & is.finite(my_stats)] # remove NAs and infinite values

  score_type <- if (all(my_stats > 0)) "pos" else if (all(my_stats < 0)) "neg" else "std"

  for (j in subcategories) {
    pathway_genes <- get_pathway_genes(j)
    pathway_genes <- pathway_genes[lengths(pathway_genes) > 0]
    if (length(pathway_genes) == 0) {
    warning(paste("Genes missing for:", j))
    next}
    #my_stats <- my_stats[names(my_stats) %in% unlist(pathway_genes)]

    # if (length(my_stats) == 0) {
    #   warning(paste("Something is wrong in:", j))
    #   next
    # }
    res <- fgsea(
      pathways = pathway_genes,
      stats = my_stats,
      eps = 0.0,
      scoreType = score_type,
      minSize = 10,
      maxSize = 500
    )

    sig_count <- sum(res$padj < 0.05, na.rm = TRUE)
    sig_pathway_counts[[length(sig_pathway_counts) + 1]] <- data.frame(
    concentration = i,
    category = j,
    sig_count = sig_count)

    sig_pathways <- res[padj < 0.05, pathway]
    sig_pathways_by_component[[j]][[i]] <- sig_pathways

    #top 10 up and down pathways
    res_clean <- res[!is.na(padj)]
    topPathwaysUp <- res_clean[NES > 0][order(padj)][1:10, pathway]
    topPathwaysDown <- res_clean[NES < 0][order(padj)][1:10, pathway]
    topPathways <- unique(c(topPathwaysUp, topPathwaysDown))

    top_res <- res[pathway %in% topPathways, .(pathway, NES)]
    top_res$concentration <- i
    top_res$subcomponent <- j

    heatmap_data_list[[paste(i, j, sep = "_")]] <- top_res

    print(plotGseaTable(
      pathway_genes[topPathways],
      my_stats,
      res,
      gseaParam = 0.5,
      colwidths = c(10, 3, 0.8, 1.2, 1.2),
      pathwayLabelStyle = list(size = 8, color = "black"),
      valueStyle = list(size = 8)
    ))
    ggsave(paste(i,j, "top_and_bottom_pathways_fgsea_results.png", sep = "_"))
    #top_leading_edge_genes[, leadingEdge := sapply(leadingEdge, paste, collapse = ";")]
    #write.csv(top_leading_edge_genes, paste0(i, "_", j, "_leading_edge_genes.csv"), row.names = FALSE)
  }
}
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# 'select()' returned 1:many mapping between keys and columns
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# CREATING STACKED GRAPHS  FOR DIFFERENTIALLY EXPRESSED PATHWAYS:

# %%
sig_df <- bind_rows(sig_pathway_counts)
sig_df$category <- factor(sig_df$category,
                          levels = c("GO:BP", "GO:CC", "GO:MF"),
                          labels = c("Biological Process", "Cellular Component", "Molecular Function"))
recode_map <- setNames(paste0(con_lis, " µM"), paste0(x, con_lis))
sig_df$concentration <- recode(sig_df$concentration, !!!recode_map)
sig_df$concentration <- factor(sig_df$concentration,
    levels = c("0.0005 µM", "0.001 µM", "0.01 µM", "0.1 µM", "0.5 µM", "1 µM", "5 µM", "10 µM", "50 µM", "100 µM"))
ggplot(sig_df, aes(x = concentration, y = sig_count, fill = category)) +
  geom_bar(stat = "identity") +
  labs(
    x = "BPA Concentration (µM)",
    y = "Number of Significantly Enriched Pathways (padj < 0.05)",
    fill = "GO Category",
    title = "Differentially Enriched GO Pathways Across BPA Doses"
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Finding commmon pathways among all concentrations:

# %%
top3 <- c(paste0(x, "5"), paste0(x, "50"), paste0(x, "10")) # only looking at conc with most patwhays, excludinh 100 as we have seen a flip so dont expect much common pathways

common_pathways <- lapply(sig_pathways_by_component, function(pathway_lists){
  top_pathways_only <- pathway_lists[names(pathway_lists) %in% top3]
  Reduce(intersect, top_pathways_only)})
print(common_pathways$`GO:BP`)
print(common_pathways$`GO:CC`)
print(common_pathways$`GO:MF`)
# Out:
#   [1] "GOBP_ACTIN_FILAMENT_BASED_PROCESS"
#   [2] "GOBP_ATTACHMENT_OF_SPINDLE_MICROTUBULES_TO_KINETOCHORE"
#   [3] "GOBP_CELL_CYCLE_CHECKPOINT_SIGNALING"
#   [4] "GOBP_CELL_CYCLE_G2_M_PHASE_TRANSITION"
#   [5] "GOBP_CELL_CYCLE_PHASE_TRANSITION"
#   [6] "GOBP_CELL_DIVISION"
#   [7] "GOBP_CENTROMERE_COMPLEX_ASSEMBLY"
#   [8] "GOBP_CENTROSOME_SEPARATION"
#   [9] "GOBP_CHROMOSOME_CONDENSATION"
#  [10] "GOBP_CHROMOSOME_LOCALIZATION"
#  [11] "GOBP_CHROMOSOME_ORGANIZATION"
#  [12] "GOBP_CHROMOSOME_ORGANIZATION_INVOLVED_IN_MEIOTIC_CELL_CYCLE"
#  [13] "GOBP_CHROMOSOME_SEGREGATION"
#  [14] "GOBP_CHROMOSOME_SEPARATION"
#  [15] "GOBP_CIRCULATORY_SYSTEM_PROCESS"
#  [16] "GOBP_CYTOKINESIS"
#  [17] "GOBP_CYTOSKELETON_DEPENDENT_CYTOKINESIS"
#  [18] "GOBP_DNA_BIOSYNTHETIC_PROCESS"
#  [19] "GOBP_DNA_CONFORMATION_CHANGE"
#  [20] "GOBP_DNA_RECOMBINATION"
#  [21] "GOBP_DNA_REPAIR"
#  [22] "GOBP_DNA_REPLICATION"
#  [23] "GOBP_DNA_REPLICATION_INITIATION"
#  [24] "GOBP_DNA_TEMPLATED_DNA_REPLICATION"
#  [25] "GOBP_DNA_TEMPLATED_DNA_REPLICATION_MAINTENANCE_OF_FIDELITY"
#  [26] "GOBP_DNA_UNWINDING_INVOLVED_IN_DNA_REPLICATION"
#  [27] "GOBP_DOUBLE_STRAND_BREAK_REPAIR"
#  [28] "GOBP_ENDOCYTOSIS"
#  [29] "GOBP_ESTABLISHMENT_OF_ORGANELLE_LOCALIZATION"
#  [30] "GOBP_EXOCYTOSIS"
#  [31] "GOBP_FEMALE_GAMETE_GENERATION"
#  [32] "GOBP_FEMALE_MEIOTIC_NUCLEAR_DIVISION"
#  [33] "GOBP_HOMOLOGOUS_CHROMOSOME_PAIRING_AT_MEIOSIS"
#  [34] "GOBP_HOMOLOGOUS_CHROMOSOME_SEGREGATION"
#  [35] "GOBP_HOMOLOGOUS_RECOMBINATION"
#  [36] "GOBP_IMPORT_INTO_CELL"
#  [37] "GOBP_KINETOCHORE_ASSEMBLY"
#  [38] "GOBP_KINETOCHORE_ORGANIZATION"
#  [39] "GOBP_MEIOSIS_I_CELL_CYCLE_PROCESS"
#  [40] "GOBP_MEIOTIC_CELL_CYCLE"
#  [41] "GOBP_MEIOTIC_CELL_CYCLE_PROCESS"
#  [42] "GOBP_MEIOTIC_CHROMOSOME_SEGREGATION"
#  [43] "GOBP_METAPHASE_CHROMOSOME_ALIGNMENT"
#  [44] "GOBP_MICROTUBULE_CYTOSKELETON_ORGANIZATION"
#  [45] "GOBP_MICROTUBULE_CYTOSKELETON_ORGANIZATION_INVOLVED_IN_MITOSIS"
#  [46] "GOBP_MICROTUBULE_ORGANIZING_CENTER_ORGANIZATION"
#  [47] "GOBP_MITOTIC_CELL_CYCLE_CHECKPOINT_SIGNALING"
#  [48] "GOBP_MITOTIC_CELL_CYCLE_PHASE_TRANSITION"
#  [49] "GOBP_MITOTIC_CHROMOSOME_CONDENSATION"
#  [50] "GOBP_MITOTIC_CYTOKINESIS"
#  [51] "GOBP_MITOTIC_DNA_INTEGRITY_CHECKPOINT_SIGNALING"
#  [52] "GOBP_MITOTIC_G2_M_TRANSITION_CHECKPOINT"
#  [53] "GOBP_MITOTIC_METAPHASE_CHROMOSOME_ALIGNMENT"
#  [54] "GOBP_MITOTIC_NUCLEAR_DIVISION"
#  [55] "GOBP_MITOTIC_SISTER_CHROMATID_SEGREGATION"
#  [56] "GOBP_MITOTIC_SISTER_CHROMATID_SEPARATION"
#  [57] "GOBP_MITOTIC_SPINDLE_ASSEMBLY"
#  [58] "GOBP_MITOTIC_SPINDLE_ORGANIZATION"
#  [59] "GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE"
#  [60] "GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE_G2_M_PHASE_TRANSITION"
#  [61] "GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE_PROCESS"
#  [62] "GOBP_NEGATIVE_REGULATION_OF_CHROMOSOME_ORGANIZATION"
#  [63] "GOBP_NEGATIVE_REGULATION_OF_CHROMOSOME_SEGREGATION"
#  [64] "GOBP_NEGATIVE_REGULATION_OF_DNA_METABOLIC_PROCESS"
#  [65] "GOBP_NEGATIVE_REGULATION_OF_DNA_RECOMBINATION"
#  [66] "GOBP_NEGATIVE_REGULATION_OF_MITOTIC_CELL_CYCLE"
#  [67] "GOBP_NEGATIVE_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION"
#  [68] "GOBP_NEGATIVE_REGULATION_OF_MULTICELLULAR_ORGANISMAL_PROCESS"
#  [69] "GOBP_NEGATIVE_REGULATION_OF_NUCLEAR_DIVISION"
#  [70] "GOBP_NEGATIVE_REGULATION_OF_ORGANELLE_ORGANIZATION"
#  [71] "GOBP_NEGATIVE_REGULATION_OF_VIRAL_GENOME_REPLICATION"
#  [72] "GOBP_NEGATIVE_REGULATION_OF_VIRAL_PROCESS"
#  [73] "GOBP_NEUROTRANSMITTER_TRANSPORT"
#  [74] "GOBP_NON_MEMBRANE_BOUNDED_ORGANELLE_ASSEMBLY"
#  [75] "GOBP_NUCLEAR_CHROMOSOME_SEGREGATION"
#  [76] "GOBP_NUCLEOSOME_ORGANIZATION"
#  [77] "GOBP_ORGANELLE_FISSION"
#  [78] "GOBP_ORGANELLE_LOCALIZATION"
#  [79] "GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE"
#  [80] "GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_PHASE_TRANSITION"
#  [81] "GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_PROCESS"
#  [82] "GOBP_POSITIVE_REGULATION_OF_CELL_DIVISION"
#  [83] "GOBP_POSITIVE_REGULATION_OF_CHROMOSOME_ORGANIZATION"
#  [84] "GOBP_POSITIVE_REGULATION_OF_CHROMOSOME_SEGREGATION"
#  [85] "GOBP_POSITIVE_REGULATION_OF_CHROMOSOME_SEPARATION"
#  [86] "GOBP_POSITIVE_REGULATION_OF_CYTOKINESIS"
#  [87] "GOBP_POSITIVE_REGULATION_OF_DNA_BIOSYNTHETIC_PROCESS"
#  [88] "GOBP_POSITIVE_REGULATION_OF_DNA_METABOLIC_PROCESS"
#  [89] "GOBP_POSITIVE_REGULATION_OF_MITOTIC_CELL_CYCLE"
#  [90] "GOBP_POSITIVE_REGULATION_OF_TRANSFERASE_ACTIVITY"
#  [91] "GOBP_PROTEIN_DNA_COMPLEX_ASSEMBLY"
#  [92] "GOBP_PROTEIN_LOCALIZATION_TO_CHROMATIN"
#  [93] "GOBP_PROTEIN_LOCALIZATION_TO_CHROMOSOME"
#  [94] "GOBP_PROTEIN_LOCALIZATION_TO_CHROMOSOME_CENTROMERIC_REGION"
#  [95] "GOBP_RECOMBINATIONAL_REPAIR"
#  [96] "GOBP_REGULATION_OF_ATTACHMENT_OF_SPINDLE_MICROTUBULES_TO_KINETOCHORE"
#  [97] "GOBP_REGULATION_OF_CELL_CYCLE_G2_M_PHASE_TRANSITION"
#  [98] "GOBP_REGULATION_OF_CELL_CYCLE_PHASE_TRANSITION"
#  [99] "GOBP_REGULATION_OF_CELL_CYCLE_PROCESS"
# [100] "GOBP_REGULATION_OF_CELL_DIVISION"
# [101] "GOBP_REGULATION_OF_CHROMOSOME_ORGANIZATION"
# [102] "GOBP_REGULATION_OF_CHROMOSOME_SEGREGATION"
# [103] "GOBP_REGULATION_OF_CYCLIN_DEPENDENT_PROTEIN_KINASE_ACTIVITY"
# [104] "GOBP_REGULATION_OF_CYTOKINESIS"
# [105] "GOBP_REGULATION_OF_DNA_METABOLIC_PROCESS"
# [106] "GOBP_REGULATION_OF_DNA_REPLICATION"
# [107] "GOBP_REGULATION_OF_DNA_TEMPLATED_DNA_REPLICATION"
# [108] "GOBP_REGULATION_OF_DNA_TEMPLATED_DNA_REPLICATION_INITIATION"
# [109] "GOBP_REGULATION_OF_KINASE_ACTIVITY"
# [110] "GOBP_REGULATION_OF_MITOTIC_CELL_CYCLE"
# [111] "GOBP_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION"
# [112] "GOBP_REGULATION_OF_MITOTIC_NUCLEAR_DIVISION"
# [113] "GOBP_REGULATION_OF_MITOTIC_SISTER_CHROMATID_SEGREGATION"
# [114] "GOBP_REGULATION_OF_NUCLEAR_DIVISION"
# [115] "GOBP_REGULATION_OF_SISTER_CHROMATID_SEGREGATION"
# [116] "GOBP_REGULATION_OF_TRANSFERASE_ACTIVITY"
# [117] "GOBP_RESPONSE_TO_WOUNDING"
# [118] "GOBP_SEXUAL_REPRODUCTION"
# [119] "GOBP_SISTER_CHROMATID_SEGREGATION"
# [120] "GOBP_SPINDLE_ASSEMBLY"
# [121] "GOBP_SPINDLE_ORGANIZATION"
# [122] "GOBP_TELOMERE_ORGANIZATION"
# [123] "GOBP_VESICLE_MEDIATED_TRANSPORT_IN_SYNAPSE"
#  [1] "GOCC_ACTIN_CYTOSKELETON"
#  [2] "GOCC_ACTIN_FILAMENT_BUNDLE"
#  [3] "GOCC_ACTOMYOSIN"
#  [4] "GOCC_CELL_CELL_JUNCTION"
#  [5] "GOCC_CELL_LEADING_EDGE"
#  [6] "GOCC_CENTRIOLE"
#  [7] "GOCC_CENTROSOME"
#  [8] "GOCC_CHROMOSOMAL_REGION"
#  [9] "GOCC_CHROMOSOME_CENTROMERIC_REGION"
# [10] "GOCC_CHROMOSOME_TELOMERIC_REGION"
# [11] "GOCC_CONDENSED_CHROMOSOME"
# [12] "GOCC_CONDENSED_CHROMOSOME_CENTROMERIC_REGION"
# [13] "GOCC_CONDENSED_NUCLEAR_CHROMOSOME"
# [14] "GOCC_DENDRITIC_TREE"
# [15] "GOCC_DNA_REPLICATION_PREINITIATION_COMPLEX"
# [16] "GOCC_INNER_KINETOCHORE"
# [17] "GOCC_INTERCELLULAR_BRIDGE"
# [18] "GOCC_KINESIN_COMPLEX"
# [19] "GOCC_MICROTUBULE"
# [20] "GOCC_MICROTUBULE_ASSOCIATED_COMPLEX"
# [21] "GOCC_MIDBODY"
# [22] "GOCC_MITOTIC_SPINDLE"
# [23] "GOCC_MITOTIC_SPINDLE_MIDZONE"
# [24] "GOCC_NUCLEAR_CHROMOSOME"
# [25] "GOCC_NUCLEOSOME"
# [26] "GOCC_OUTER_KINETOCHORE"
# [27] "GOCC_POLYMERIC_CYTOSKELETAL_FIBER"
# [28] "GOCC_PRESYNAPSE"
# [29] "GOCC_REPLICATION_FORK"
# [30] "GOCC_SPINDLE"
# [31] "GOCC_SPINDLE_MICROTUBULE"
# [32] "GOCC_SPINDLE_MIDZONE"
# [33] "GOCC_SPINDLE_POLE"
#  [1] "GOMF_ATP_DEPENDENT_ACTIVITY"
#  [2] "GOMF_ATP_DEPENDENT_ACTIVITY_ACTING_ON_DNA"
#  [3] "GOMF_ATP_DEPENDENT_DNA_DAMAGE_SENSOR_ACTIVITY"
#  [4] "GOMF_ATP_HYDROLYSIS_ACTIVITY"
#  [5] "GOMF_CATALYTIC_ACTIVITY_ACTING_ON_A_NUCLEIC_ACID"
#  [6] "GOMF_CATALYTIC_ACTIVITY_ACTING_ON_DNA"
#  [7] "GOMF_CYTOSKELETAL_MOTOR_ACTIVITY"
#  [8] "GOMF_DNA_HELICASE_ACTIVITY"
#  [9] "GOMF_FOUR_WAY_JUNCTION_DNA_BINDING"
# [10] "GOMF_MICROTUBULE_BINDING"
# [11] "GOMF_MICROTUBULE_MOTOR_ACTIVITY"
# [12] "GOMF_SINGLE_STRANDED_DNA_HELICASE_ACTIVITY"
# [13] "GOMF_STRUCTURAL_CONSTITUENT_OF_CHROMATIN"
# [14] "GOMF_STRUCTURAL_MOLECULE_ACTIVITY"
# [15] "GOMF_TUBULIN_BINDING"

# %% [markdown]
# To comapre against the estradiol conc we will also look at some more concs

# %%
top3 <- c(paste0(x, "0.0005"), paste0(x, "0.001"), paste0(x, "0.01")) # only looking at conc with most patwhays, excludinh 100 as we have seen a flip so dont expect much common pathways

common_pathways <- lapply(sig_pathways_by_component, function(pathway_lists){
  top_pathways_only <- pathway_lists[names(pathway_lists) %in% top3]
  Reduce(intersect, top_pathways_only)})
print(common_pathways$`GO:BP`)
print(common_pathways$`GO:CC`)
print(common_pathways$`GO:MF`)
# Out:
#  [1] "GOBP_ATTACHMENT_OF_SPINDLE_MICROTUBULES_TO_KINETOCHORE"
#  [2] "GOBP_CELL_CYCLE_CHECKPOINT_SIGNALING"
#  [3] "GOBP_CELL_CYCLE_G2_M_PHASE_TRANSITION"
#  [4] "GOBP_CELL_CYCLE_PHASE_TRANSITION"
#  [5] "GOBP_CELL_DIVISION"
#  [6] "GOBP_CENTROMERE_COMPLEX_ASSEMBLY"
#  [7] "GOBP_CHROMOSOME_LOCALIZATION"
#  [8] "GOBP_CHROMOSOME_ORGANIZATION"
#  [9] "GOBP_CHROMOSOME_SEGREGATION"
# [10] "GOBP_CHROMOSOME_SEPARATION"
# [11] "GOBP_DNA_CONFORMATION_CHANGE"
# [12] "GOBP_DNA_RECOMBINATION"
# [13] "GOBP_DNA_REPAIR"
# [14] "GOBP_DNA_REPLICATION"
# [15] "GOBP_DNA_REPLICATION_INITIATION"
# [16] "GOBP_DNA_TEMPLATED_DNA_REPLICATION"
# [17] "GOBP_DOUBLE_STRAND_BREAK_REPAIR"
# [18] "GOBP_FEMALE_MEIOTIC_NUCLEAR_DIVISION"
# [19] "GOBP_HOMOLOGOUS_CHROMOSOME_SEGREGATION"
# [20] "GOBP_HOMOLOGOUS_RECOMBINATION"
# [21] "GOBP_IMPORT_INTO_CELL"
# [22] "GOBP_KINETOCHORE_ASSEMBLY"
# [23] "GOBP_KINETOCHORE_ORGANIZATION"
# [24] "GOBP_MEIOSIS_I_CELL_CYCLE_PROCESS"
# [25] "GOBP_MEIOTIC_CELL_CYCLE"
# [26] "GOBP_MEIOTIC_CELL_CYCLE_PROCESS"
# [27] "GOBP_MEIOTIC_CHROMOSOME_SEGREGATION"
# [28] "GOBP_METAPHASE_CHROMOSOME_ALIGNMENT"
# [29] "GOBP_MICROTUBULE_CYTOSKELETON_ORGANIZATION"
# [30] "GOBP_MICROTUBULE_CYTOSKELETON_ORGANIZATION_INVOLVED_IN_MITOSIS"
# [31] "GOBP_MITOTIC_CELL_CYCLE_CHECKPOINT_SIGNALING"
# [32] "GOBP_MITOTIC_CELL_CYCLE_PHASE_TRANSITION"
# [33] "GOBP_MITOTIC_CYTOKINESIS"
# [34] "GOBP_MITOTIC_NUCLEAR_DIVISION"
# [35] "GOBP_MITOTIC_SISTER_CHROMATID_SEGREGATION"
# [36] "GOBP_MITOTIC_SISTER_CHROMATID_SEPARATION"
# [37] "GOBP_MITOTIC_SPINDLE_ORGANIZATION"
# [38] "GOBP_NEGATIVE_REGULATION_OF_CELL_CYCLE_PROCESS"
# [39] "GOBP_NEGATIVE_REGULATION_OF_CHROMOSOME_ORGANIZATION"
# [40] "GOBP_NEGATIVE_REGULATION_OF_CHROMOSOME_SEGREGATION"
# [41] "GOBP_NEGATIVE_REGULATION_OF_MITOTIC_CELL_CYCLE"
# [42] "GOBP_NEGATIVE_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION"
# [43] "GOBP_NEGATIVE_REGULATION_OF_NUCLEAR_DIVISION"
# [44] "GOBP_NEGATIVE_REGULATION_OF_VIRAL_GENOME_REPLICATION"
# [45] "GOBP_NON_MEMBRANE_BOUNDED_ORGANELLE_ASSEMBLY"
# [46] "GOBP_NUCLEAR_CHROMOSOME_SEGREGATION"
# [47] "GOBP_ORGANELLE_FISSION"
# [48] "GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE"
# [49] "GOBP_POSITIVE_REGULATION_OF_CELL_CYCLE_PROCESS"
# [50] "GOBP_POSITIVE_REGULATION_OF_MITOTIC_CELL_CYCLE"
# [51] "GOBP_PROTEIN_DNA_COMPLEX_ASSEMBLY"
# [52] "GOBP_REGULATION_OF_ATTACHMENT_OF_SPINDLE_MICROTUBULES_TO_KINETOCHORE"
# [53] "GOBP_REGULATION_OF_CELL_CYCLE_G2_M_PHASE_TRANSITION"
# [54] "GOBP_REGULATION_OF_CELL_CYCLE_PHASE_TRANSITION"
# [55] "GOBP_REGULATION_OF_CELL_CYCLE_PROCESS"
# [56] "GOBP_REGULATION_OF_CHROMOSOME_ORGANIZATION"
# [57] "GOBP_REGULATION_OF_CHROMOSOME_SEGREGATION"
# [58] "GOBP_REGULATION_OF_DNA_METABOLIC_PROCESS"
# [59] "GOBP_REGULATION_OF_MITOTIC_CELL_CYCLE"
# [60] "GOBP_REGULATION_OF_MITOTIC_CELL_CYCLE_PHASE_TRANSITION"
# [61] "GOBP_REGULATION_OF_MITOTIC_NUCLEAR_DIVISION"
# [62] "GOBP_REGULATION_OF_MITOTIC_SISTER_CHROMATID_SEGREGATION"
# [63] "GOBP_REGULATION_OF_NUCLEAR_DIVISION"
# [64] "GOBP_REGULATION_OF_SISTER_CHROMATID_SEGREGATION"
# [65] "GOBP_SISTER_CHROMATID_SEGREGATION"
# [66] "GOBP_SPINDLE_ORGANIZATION"
#  [1] "GOCC_CHROMOSOMAL_REGION"
#  [2] "GOCC_CHROMOSOME_CENTROMERIC_REGION"
#  [3] "GOCC_CONDENSED_CHROMOSOME"
#  [4] "GOCC_CONDENSED_CHROMOSOME_CENTROMERIC_REGION"
#  [5] "GOCC_INNER_KINETOCHORE"
#  [6] "GOCC_INTERCELLULAR_BRIDGE"
#  [7] "GOCC_KINESIN_COMPLEX"
#  [8] "GOCC_LARGE_RIBOSOMAL_SUBUNIT"
#  [9] "GOCC_MICROTUBULE"
# [10] "GOCC_MICROTUBULE_ASSOCIATED_COMPLEX"
# [11] "GOCC_MITOCHONDRIAL_MATRIX"
# [12] "GOCC_MITOCHONDRIAL_PROTEIN_CONTAINING_COMPLEX"
# [13] "GOCC_MITOTIC_SPINDLE"
# [14] "GOCC_NUCLEOSOME"
# [15] "GOCC_OUTER_KINETOCHORE"
# [16] "GOCC_POLYMERIC_CYTOSKELETAL_FIBER"
# [17] "GOCC_RIBOSOMAL_SUBUNIT"
# [18] "GOCC_RIBOSOME"
# [19] "GOCC_SPINDLE"
# [20] "GOCC_SPINDLE_MIDZONE"
# [21] "GOCC_SUPRAMOLECULAR_POLYMER"
# [1] "GOMF_ATP_DEPENDENT_ACTIVITY_ACTING_ON_DNA"
# [2] "GOMF_CATALYTIC_ACTIVITY_ACTING_ON_DNA"
# [3] "GOMF_DNA_HELICASE_ACTIVITY"
# [4] "GOMF_MICROTUBULE_BINDING"
# [5] "GOMF_MICROTUBULE_MOTOR_ACTIVITY"
# [6] "GOMF_STRUCTURAL_CONSTITUENT_OF_CHROMATIN"
# [7] "GOMF_STRUCTURAL_CONSTITUENT_OF_RIBOSOME"
# [8] "GOMF_STRUCTURAL_MOLECULE_ACTIVITY"
# [9] "GOMF_TUBULIN_BINDING"

# %% [markdown]
# COMPARING THE DATA WITH THE 50 GENE BIOMARKERS FOR ESTROGEN RESPONSE

# %%
file <- read.csv("/content/biomarkers.csv")
biomarker_df <- file[!is.na(file$Fold.change.in.the.46.gene.ER.Biomarker), ]
biomarker_genes <- biomarker_df$Gene
reference_fc <- biomarker_df$Fold.change.in.the.46.gene.ER.Biomarker
names(reference_fc) <- biomarker_genes
biomarker_gene_set <- list("Estrogen_Biomarkers" = biomarker_genes)
lfc_matrix <- data.frame(Gene = biomarker_genes)
for (i in names(control_files)) {
  file <- control_files[[i]]
  stats <- get_stats(file)
  stats <- sort(stats, decreasing = TRUE)
  stats <- stats[!is.na(names(stats)) & is.finite(stats)]
  estrogen_res <- fgsea(pathways = biomarker_gene_set, stats = stats, scoreType = "std", minSize = 1, maxSize = 500)
  print(estrogen_res)
  topPathwaysUp <- estrogen_res[ES > 0][head(order(pval), n = 10), pathway]
  topPathwaysDown <- estrogen_res[ES < 0][head(order(pval), n = 10), pathway]
  topPathways <- c(topPathwaysUp, rev(topPathwaysDown))
  print(plotGseaTable(
    biomarker_gene_set[topPathways],
    stats,
    estrogen_res,
    gseaParam = 0.5,
    colwidths = c(10, 3, 0.8, 1.2, 1.2),
    pathwayLabelStyle = list(size = 8, color = "black"),
    valueStyle = list(size = 8)
  ))
  common_genes <- intersect(biomarker_genes, names(stats))
  estrogen_gene_stats <- data.frame(
    Gene                = common_genes,
    Log2FC              = stats[common_genes],
    Reference           = reference_fc[common_genes],
    Regulation          = ifelse(stats[common_genes] > 0, "Upregulated", "Downregulated"),
    Reference_Regulation = ifelse(reference_fc[common_genes] > 0, "Upregulated", "Downregulated")
  )
  print(estrogen_gene_stats)
  match_up <- sum(estrogen_gene_stats$Reference_Regulation == "Upregulated" & estrogen_gene_stats$Regulation == "Upregulated")
  match_down <- sum(estrogen_gene_stats$Reference_Regulation == "Downregulated" & estrogen_gene_stats$Regulation == "Downregulated")
  total_up <- sum(estrogen_gene_stats$Reference_Regulation == "Upregulated")
  total_down <- sum(estrogen_gene_stats$Reference_Regulation == "Downregulated")
  cat("Upregulated match:", match_up, "out of", total_up, "\n")
  cat("Downregulated match:", match_down, "out of", total_down, "\n")
  temp_df <- data.frame(Gene = common_genes, log2FC = stats[common_genes])
  colnames(temp_df)[2] <- i
  lfc_matrix <- full_join(lfc_matrix, temp_df, by = "Gene")
}

lfc_matrix$Reference <- reference_fc[lfc_matrix$Gene]
rownames(lfc_matrix) <- lfc_matrix$Gene
lfc_matrix <- lfc_matrix[, -1]
recode_map <- setNames(paste0(con_lis, " µM"), paste0(x, con_lis))
lfc_matrix <- lfc_matrix %>%
  rename_with(~ recode(., !!!recode_map))
ordered_cols <- c("Reference", "0.0005 µM", "0.001 µM", "0.01 µM", "0.1 µM", "0.5 µM", "1 µM", "5 µM", "10 µM", "50 µM", "100 µM")
lfc_matrix <- lfc_matrix[, intersect(ordered_cols, colnames(lfc_matrix))]
lfc_matrix[!is.finite(as.matrix(lfc_matrix))] <- 0
lfc_matrix_t <- t(lfc_matrix)
n_genes <- ncol(lfc_matrix_t)
n_conditions <- nrow(lfc_matrix_t)
cell_width <- 0.4
cell_height <- 0.4
pdf("BPA_biomarker_heatmap.pdf", width = 12, height = 8)
pheatmap(
  mat = lfc_matrix_t,
  cluster_rows = FALSE,
  cluster_cols = TRUE,
  display_numbers = round(lfc_matrix_t, 2),
  main = "Estrogen Biomarker Log2FC vs Estradiol Doses",
  fontsize_col = 8,
  fontsize_row = 10,
  angle_col = 90,
  color = colorRampPalette(c("blue", "white", "red"))(200),
  na_col = "grey90",
  gaps_row = 1,
  border_color = NA
)
dev.off()
# Out:
# 'select()' returned 1:many mapping between keys and columns
#                pathway        pval        padj   log2err       ES     NES  size
#                 <char>       <num>       <num>     <num>    <num>   <num> <int>
# 1: Estrogen_Biomarkers 0.006689979 0.006689979 0.4070179 0.467458 1.63236    41
#     leadingEdge
#          <list>
# 1: RET, RBB....
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.397404747    1.3686 Downregulated          Upregulated
# PDZK1       PDZK1  0.396926130    1.4229   Upregulated          Upregulated
# RET           RET  1.055061673    1.6957   Upregulated          Upregulated
# PGR           PGR  0.640134955    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.613965236    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.455637534    1.4629   Upregulated          Upregulated
# CA12         CA12  0.439509899    1.3283   Upregulated          Upregulated
# MYB           MYB  0.543809134    1.2700   Upregulated          Upregulated
# AREG         AREG  0.388133573    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.036559406    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.090092199    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1 -0.025101162   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.294679421   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.163594992   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.025550513   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.008584321   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.663550372   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.390661768   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.315723565   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.093553921   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.342900646   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.372071817   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.168060726   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.336345943   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  1.001109072    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.208251789    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.206164672    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.215951919    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.341004418    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.104689367    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.114983774    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.203825959    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.059071850    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.211697776    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.552367934    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.254799936    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR -0.004762325    1.5783 Downregulated          Upregulated
# NMRK1       NMRK1 -0.472330744    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.241559760    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.226935520    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  0.793919751    1.9014   Upregulated          Upregulated
# Upregulated match: 21 out of 28
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 4.867882e-06 4.867882e-06 0.6105269 0.6612813 2.120522
#     size  leadingEdge
#    <int>       <list>
# 1:    40 PDZK1, P....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.61202205    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  2.62092186    1.4229   Upregulated          Upregulated
# RET           RET  1.62217507    1.6957   Upregulated          Upregulated
# PGR           PGR  1.96813230    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.45772474    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.20212593    1.4629   Upregulated          Upregulated
# CA12         CA12  0.62441292    1.3283   Upregulated          Upregulated
# MYB           MYB  1.13102084    1.2700   Upregulated          Upregulated
# AREG         AREG  1.66379268    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.30573911    1.2917   Upregulated          Upregulated
# CD44         CD44  0.53042961    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.04047578   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.44866298   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.63160688   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.36769088   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.07211516   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -1.11615483   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.35841397   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.47392195   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.17453669   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.74571433   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3 -0.15286995   -1.2943 Downregulated        Downregulated
# RHBDF1     RHBDF1 -0.18525792   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -0.41835614   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2  0.50409333    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.72803397    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.38063558    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.94272803    1.3643   Upregulated          Upregulated
# WWC1         WWC1 -0.09083202    1.4183 Downregulated          Upregulated
# FOXC1       FOXC1 -0.19412244    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.44608685    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.13947509    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.40873825    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  1.02153316    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.10950997    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.50226935    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1  0.07814848    1.6229   Upregulated          Upregulated
# JAK2         JAK2  0.57917160    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.49515184    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.75763629    1.9014   Upregulated          Upregulated
# Upregulated match: 23 out of 27
# Downregulated match: 12 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 0.0003826535 0.0003826535 0.4984931 0.5701535 1.923423
#     size  leadingEdge
#    <int>       <list>
# 1:    39 RET, PDZ....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.176095344    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  1.234639042    1.4229   Upregulated          Upregulated
# RET           RET  1.362676411    1.6957   Upregulated          Upregulated
# PGR           PGR  0.974497864    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.866307714    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.804353958    1.4629   Upregulated          Upregulated
# CA12         CA12  0.512674078    1.3283   Upregulated          Upregulated
# MYB           MYB  0.679271018    1.2700   Upregulated          Upregulated
# AREG         AREG  1.045920728    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.264189339    1.2917   Upregulated          Upregulated
# CD44         CD44  0.276750288    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.080161029   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.348022478   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.015127704   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.526603537   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.013706367   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.758189098   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.469234315   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.460104540   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.133524127   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.500716033   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.401971492   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.074287120   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.469909918   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.859041723    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.210646780    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.540216366    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.455130128    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.556606881    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.044024560    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.576397383    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.151075892    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.107021333    1.4217   Upregulated          Upregulated
# SVIL         SVIL -0.001602087    1.4400 Downregulated          Upregulated
# ABHD2       ABHD2  0.585897109    1.4543   Upregulated          Upregulated
# SMOX         SMOX  0.149268277    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  0.055223342    1.5783   Upregulated          Upregulated
# SGK1         SGK1 -0.289191536    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.066466687    1.9014   Upregulated          Upregulated
# Upregulated match: 23 out of 26
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj    log2err        ES       NES  size
#                 <char>     <num>     <num>      <num>     <num>     <num> <int>
# 1: Estrogen_Biomarkers 0.5168539 0.5168539 0.07399014 0.2659357 0.9569531    40
#     leadingEdge
#          <list>
# 1: RBBP8, R....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23 -0.48314556    1.3686 Downregulated          Upregulated
# RET           RET  0.76260521    1.6957   Upregulated          Upregulated
# PGR           PGR  0.02288105    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.23932141    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.16831155    1.4629   Upregulated          Upregulated
# CA12         CA12  0.02159454    1.3283   Upregulated          Upregulated
# MYB           MYB  0.38386262    1.2700   Upregulated          Upregulated
# AREG         AREG  0.08892666    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.37056816    1.2917   Upregulated          Upregulated
# CD44         CD44 -0.07931385    1.4567 Downregulated          Upregulated
# EFNA1       EFNA1  0.16154712   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.16050524   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.34421883   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.46628584   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.13997649   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.57328725   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.44314099   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.18452251   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.01761961   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.32547006   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.62729813   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.39335073   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.35102868   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  1.07426579    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.02511048    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.19446920    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.10256479    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.31200840    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.14096653    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.34758433    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.12938029    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.04505193    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.16900667    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.26061433    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.37979866    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.12735463    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.53985243    1.6229 Downregulated          Upregulated
# JAK2         JAK2 -0.27819452    1.6717 Downregulated          Upregulated
# SGK1         SGK1 -0.02691663    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  0.18960148    1.9014   Upregulated          Upregulated
# Upregulated match: 20 out of 27
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway        pval        padj   log2err        ES      NES
#                 <char>       <num>       <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 0.005105021 0.005105021 0.4070179 0.5049254 1.727135
#     size  leadingEdge
#    <int>       <list>
# 1:    40 RET, PGR....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.076910027    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  1.164437192    1.4229   Upregulated          Upregulated
# RET           RET  1.599328855    1.6957   Upregulated          Upregulated
# PGR           PGR  1.480940116    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  0.848866638    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  0.866533725    1.4629   Upregulated          Upregulated
# CA12         CA12  0.230610711    1.3283   Upregulated          Upregulated
# MYB           MYB  0.828818588    1.2700   Upregulated          Upregulated
# AREG         AREG  0.669717032    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.539176062    1.2917   Upregulated          Upregulated
# CD44         CD44  0.168131605    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1  0.025763760   -1.4800   Upregulated        Downregulated
# CCNG2       CCNG2 -0.344014810   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.317773136   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.378657968   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.120949415   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.687166548   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.455748914   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.491532073   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.393882636   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.597186113   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.379534595   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.166383519   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.465146804   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2  0.055848614    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.466379849    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.342325978    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.405358814    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.151359163    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1  0.006645806    1.4200   Upregulated          Upregulated
# CCND1       CCND1  0.253714548    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.129891694    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.158874903    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.780897633    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.141792570    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.082985073    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.400806412    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.063089733    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.722700366    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  0.945606232    1.9014   Upregulated          Upregulated
# Upregulated match: 24 out of 27
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 2.199206e-05 2.199206e-05 0.5756103 0.6202414 2.116449
#     size  leadingEdge
#    <int>       <list>
# 1:    41 PDZK1, R....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.60515764    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  2.08860087    1.4229   Upregulated          Upregulated
# RET           RET  2.03806907    1.6957   Upregulated          Upregulated
# PGR           PGR  1.91999443    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.13509223    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.31858898    1.4629   Upregulated          Upregulated
# CA12         CA12  0.57741495    1.3283   Upregulated          Upregulated
# MYB           MYB  1.18464966    1.2700   Upregulated          Upregulated
# AREG         AREG  1.11433751    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.51918298    1.2917   Upregulated          Upregulated
# CD44         CD44  0.39304689    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.09533927   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.38024296   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.34414492   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.44357407   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.10401354   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -0.83455810   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.50659162   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.45276194   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.29216158   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.76025705   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.36986887   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.12377225   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.86726722   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.92788421    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.42828335    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.58124729    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.36580123    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.55089888    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.15556810    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.22029052    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.36367881    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.15737178    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.45741023    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.99089819    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.06693751    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.24444942    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.37545275    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.79676143    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.32008619    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.20302521    1.9014   Upregulated          Upregulated
# Upregulated match: 24 out of 28
# Downregulated match: 10 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 7.887899e-05 7.887899e-05 0.5384341 0.5969821 2.049621
#     size  leadingEdge
#    <int>       <list>
# 1:    41 PDZK1, P....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.42701706    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  2.78287824    1.4229   Upregulated          Upregulated
# RET           RET  2.11382530    1.6957   Upregulated          Upregulated
# PGR           PGR  2.40213750    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.42059711    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.79031929    1.4629   Upregulated          Upregulated
# CA12         CA12  0.86472196    1.3283   Upregulated          Upregulated
# MYB           MYB  1.43759958    1.2700   Upregulated          Upregulated
# AREG         AREG  1.57340938    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.37246333    1.2917   Upregulated          Upregulated
# CD44         CD44  0.33415265    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.11130761   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.52243636   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.39792281   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.70121964   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.03751673   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -1.08007206   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.54958504   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.71281603   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.25907274   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.94149710   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.60358379   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1  0.03189017   -1.2700   Upregulated        Downregulated
# ALAD         ALAD -0.79041361   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  1.24452053    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2  0.13105833    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.78694347    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.55751877    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.85005753    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.22880322    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.38817222    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.49220083    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.34058570    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.16786481    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  1.04212976    1.4543   Upregulated          Upregulated
# SMOX         SMOX  0.17595822    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  0.42005278    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.45238220    1.6229 Downregulated          Upregulated
# JAK2         JAK2  0.26194440    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.27664318    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  2.00383858    1.9014   Upregulated          Upregulated
# Upregulated match: 25 out of 28
# Downregulated match: 9 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 8.793379e-06 8.793379e-06 0.5933255 0.6728345 2.170556
#     size  leadingEdge
#    <int>       <list>
# 1:    40 PDZK1, P....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.91268207    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  2.78837700    1.4229   Upregulated          Upregulated
# RET           RET  1.90293892    1.6957   Upregulated          Upregulated
# PGR           PGR  2.18883038    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.44162485    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.61489685    1.4629   Upregulated          Upregulated
# CA12         CA12  0.83178888    1.3283   Upregulated          Upregulated
# MYB           MYB  1.37724901    1.2700   Upregulated          Upregulated
# AREG         AREG  1.88328818    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.54802287    1.2917   Upregulated          Upregulated
# CD44         CD44  0.45553679    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.21668837   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.36491832   -1.7650 Downregulated        Downregulated
# EPHA4       EPHA4  0.69900115   -1.5171   Upregulated        Downregulated
# TFPI         TFPI -0.79663675   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.10734751   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -1.30926301   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.42558583   -1.4450 Downregulated        Downregulated
# ID3           ID3 -0.60361041   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2 -0.20219028   -1.3517 Downregulated        Downregulated
# KYNU         KYNU -0.72732111   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3  0.55447996   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1 -0.29504812   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -0.68753119   -1.2643 Downregulated        Downregulated
# SIAH2       SIAH2  0.73474065    1.2500   Upregulated          Upregulated
# SLC7A5     SLC7A5  0.75780945    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.31171095    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.87113594    1.3643   Upregulated          Upregulated
# WWC1         WWC1  0.02258649    1.4183   Upregulated          Upregulated
# FOXC1       FOXC1 -0.57743815    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.63054787    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C  0.27141800    1.4217   Upregulated          Upregulated
# SVIL         SVIL  0.31449563    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  1.12595119    1.4543   Upregulated          Upregulated
# SMOX         SMOX  0.04509670    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  0.50969242    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1  0.47342812    1.6229   Upregulated          Upregulated
# JAK2         JAK2  0.63014008    1.6717   Upregulated          Upregulated
# SGK1         SGK1 -0.34456716    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.83991105    1.9014   Upregulated          Upregulated
# Upregulated match: 25 out of 27
# Downregulated match: 11 out of 13
# 'select()' returned 1:many mapping between keys and columns
#                pathway         pval         padj   log2err        ES      NES
#                 <char>        <num>        <num>     <num>     <num>    <num>
# 1: Estrogen_Biomarkers 6.248331e-05 6.248331e-05 0.5384341 0.6087126 2.052789
#     size  leadingEdge
#    <int>       <list>
# 1:    39 AREG, PD....
# plot without title
#              Gene       Log2FC Reference    Regulation Reference_Regulation
# PRSS23     PRSS23  0.468300239    1.3686   Upregulated          Upregulated
# PDZK1       PDZK1  1.963807428    1.4229   Upregulated          Upregulated
# RET           RET  1.221736981    1.6957   Upregulated          Upregulated
# PGR           PGR  1.784748622    1.3750   Upregulated          Upregulated
# CXCL12     CXCL12  1.580474258    1.6200   Upregulated          Upregulated
# RAPGEFL1 RAPGEFL1  1.662324113    1.4629   Upregulated          Upregulated
# CA12         CA12  0.865032390    1.3283   Upregulated          Upregulated
# MYB           MYB  0.992411289    1.2700   Upregulated          Upregulated
# AREG         AREG  2.005032601    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.230293340    1.2917   Upregulated          Upregulated
# CD44         CD44  0.518117637    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.235677406   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -0.534011123   -1.7650 Downregulated        Downregulated
# TFPI         TFPI -0.417636090   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A -0.126384284   -1.4817 Downregulated        Downregulated
# CLMN         CLMN -1.172203235   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.265893383   -1.4450 Downregulated        Downregulated
# ID3           ID3 -1.018235170   -1.4200 Downregulated        Downregulated
# DYRK2       DYRK2  0.055647728   -1.3517   Upregulated        Downregulated
# KYNU         KYNU -0.476630313   -1.3133 Downregulated        Downregulated
# PIK3R3     PIK3R3 -0.116991932   -1.2943 Downregulated        Downregulated
# RHBDF1     RHBDF1 -0.091160198   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -0.544672978   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  1.211454373    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2 -0.001956005    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  0.942757425    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.428831067    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1  0.511169127    1.3643   Upregulated          Upregulated
# WWC1         WWC1 -0.049593274    1.4183 Downregulated          Upregulated
# FOXC1       FOXC1 -0.629348098    1.4200 Downregulated          Upregulated
# CCND1       CCND1  0.669273425    1.4217   Upregulated          Upregulated
# TFAP2C     TFAP2C -0.005409569    1.4217 Downregulated          Upregulated
# SVIL         SVIL  0.286871158    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.913329757    1.4543   Upregulated          Upregulated
# SMOX         SMOX -0.357036336    1.4729 Downregulated          Upregulated
# PLAUR       PLAUR  0.010890158    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.550318654    1.6229 Downregulated          Upregulated
# SGK1         SGK1 -0.428470011    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1  1.488221435    1.9014   Upregulated          Upregulated
# Upregulated match: 20 out of 27
# Downregulated match: 11 out of 12
# 'select()' returned 1:many mapping between keys and columns
#                pathway      pval      padj   log2err        ES       NES  size
#                 <char>     <num>     <num>     <num>     <num>     <num> <int>
# 1: Estrogen_Biomarkers 0.1594684 0.1594684 0.1404062 -0.392758 -1.278124    36
#     leadingEdge
#          <list>
# 1: MYB, TFP....
# plot without title
#              Gene      Log2FC Reference    Regulation Reference_Regulation
# PGR           PGR -0.81416887    1.3750 Downregulated          Upregulated
# CXCL12     CXCL12 -0.87262717    1.6200 Downregulated          Upregulated
# RAPGEFL1 RAPGEFL1 -0.27620792    1.4629 Downregulated          Upregulated
# CA12         CA12 -1.15923169    1.3283 Downregulated          Upregulated
# MYB           MYB -2.63570313    1.2700 Downregulated          Upregulated
# AREG         AREG  2.47706693    1.5957   Upregulated          Upregulated
# RCL1         RCL1  0.33711151    1.2917   Upregulated          Upregulated
# CD44         CD44  0.93451716    1.4567   Upregulated          Upregulated
# EFNA1       EFNA1 -0.44311934   -1.4800 Downregulated        Downregulated
# CCNG2       CCNG2 -1.37928457   -1.7650 Downregulated        Downregulated
# TFPI         TFPI -2.19416596   -1.4943 Downregulated        Downregulated
# TFAP2A     TFAP2A  0.24501483   -1.4817   Upregulated        Downregulated
# CLMN         CLMN -0.64351671   -1.4450 Downregulated        Downregulated
# PLEKHF2   PLEKHF2 -0.26107223   -1.4450 Downregulated        Downregulated
# ID3           ID3  0.48959766   -1.4200   Upregulated        Downregulated
# DYRK2       DYRK2  0.39023621   -1.3517   Upregulated        Downregulated
# KYNU         KYNU  0.29257707   -1.3133   Upregulated        Downregulated
# PIK3R3     PIK3R3  0.04676851   -1.2943   Upregulated        Downregulated
# RHBDF1     RHBDF1 -0.92966803   -1.2700 Downregulated        Downregulated
# ALAD         ALAD -1.09279561   -1.2643 Downregulated        Downregulated
# RBBP8       RBBP8  0.93300873    1.2417   Upregulated          Upregulated
# SIAH2       SIAH2 -0.47509179    1.2500 Downregulated          Upregulated
# SLC7A5     SLC7A5  2.19860940    1.3500   Upregulated          Upregulated
# MICAL2     MICAL2  0.84601989    1.3500   Upregulated          Upregulated
# OLFM1       OLFM1 -1.21058739    1.3643 Downregulated          Upregulated
# WWC1         WWC1 -0.25796295    1.4183 Downregulated          Upregulated
# FOXC1       FOXC1 -1.11449154    1.4200 Downregulated          Upregulated
# CCND1       CCND1 -0.91789229    1.4217 Downregulated          Upregulated
# TFAP2C     TFAP2C -0.75968474    1.4217 Downregulated          Upregulated
# SVIL         SVIL  1.06862178    1.4400   Upregulated          Upregulated
# ABHD2       ABHD2  0.20922979    1.4543   Upregulated          Upregulated
# SMOX         SMOX  0.73419990    1.4729   Upregulated          Upregulated
# PLAUR       PLAUR  2.44581748    1.5783   Upregulated          Upregulated
# NMRK1       NMRK1 -0.23954194    1.6229 Downregulated          Upregulated
# SGK1         SGK1 -1.31460858    1.8114 Downregulated          Upregulated
# MYBL1       MYBL1 -0.68833331    1.9014 Downregulated          Upregulated
# Upregulated match: 10 out of 24
# Downregulated match: 7 out of 12
# plot without title
# pdf
#   3
# plot without title

# %%
write.csv(lfc_matrix_t,file=paste0(x,"_estroBiomarker_Mat.csv"))
